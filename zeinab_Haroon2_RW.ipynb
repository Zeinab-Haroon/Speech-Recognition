# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pip install torchaudio
# !pip install PyDrive
# !pip install soundfile
# Out:
# Collecting torchaudio
#   Downloading https://files.pythonhosted.org/packages/e9/0a/40e53c686c2af65b2a4e818d11d9b76fa79178440caf99f3ceb2a32c3b04/torchaudio-0.5.1-cp36-cp36m-manylinux1_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 3.4MB/s
# Requirement already satisfied: torch==1.5.1 in /usr/local/lib/python3.6/dist-packages (from torchaudio) (1.5.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==1.5.1->torchaudio) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.5.1->torchaudio) (0.16.0)
# Installing collected packages: torchaudio
# Successfully installed torchaudio-0.5.1
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.7.12)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.17.2)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.12.0)
# Requirement already satisfied: httplib2<1dev,>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.17.4)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.0.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.8)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (4.6)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->PyDrive) (47.3.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->PyDrive) (4.1.0)
# Collecting soundfile
#   Downloading https://files.pythonhosted.org/packages/eb/f2/3cbbbf3b96fb9fa91582c438b574cff3f45b29c772f94c400e2c99ef5db9/SoundFile-0.10.3.post1-py2.py3-none-any.whl
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.6/dist-packages (from soundfile) (1.14.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.0->soundfile) (2.20)
# Installing collected packages: soundfile
# Successfully installed soundfile-0.10.3.post1

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
downloaded = drive.CreateFile({'id':"1SceZ97xNyHDev-UbnBtlJFn9RJ_Skg6I"}) 
downloaded.GetContentFile('train_data.zip')
# !unzip train_data.zip -d train_data
downloaded = drive.CreateFile({'id':"1UlOc9K5owvP0R6x02sRq4s2zAXuKzaZR"}) 
downloaded.GetContentFile('val_data.zip')
# !unzip val_data.zip -d val_data
# !ls
# Out:
# Archive:  train_data.zip
#  extracting: train_data/1081/125237/1081-125237-0004.flac
#  extracting: train_data/1081/125237/1081-125237-0006.flac
#  extracting: train_data/1081/125237/1081-125237-0009.flac
#  extracting: train_data/1081/125237/1081-125237-0012.flac
#  extracting: train_data/1081/125237/1081-125237-0014.flac
#  extracting: train_data/1081/125237/1081-125237-0016.flac
#  extracting: train_data/1081/125237/1081-125237-0032.flac
#  extracting: train_data/1081/125237/1081-125237-0039.flac
#  extracting: train_data/1081/125237/1081-125237-0040.flac
#  extracting: train_data/1081/125237/1081-125237-0042.flac
#  extracting: train_data/1081/125237/1081-125237-0053.flac
#  extracting: train_data/1081/125237/1081-125237-0054.flac
#  extracting: train_data/1081/125237/1081-125237-0058.flac
#  extracting: train_data/1081/125237/1081-125237-0059.flac
#  extracting: train_data/1081/125237/1081-125237-0064.flac
#  extracting: train_data/1081/125237/1081-125237-0065.flac
#  extracting: train_data/1081/125237/1081-125237-0068.flac
#  extracting: train_data/1081/125237/1081-125237-0079.flac
#  extracting: train_data/1081/125237/1081-125237-0080.flac
#  extracting: train_data/1081/125237/1081-125237-0081.flac
#  extracting: train_data/1081/125237/1081-125237-0082.flac
#  extracting: train_data/1081/125237/1081-125237-0084.flac
#  extracting: train_data/1081/125237/1081-125237-0086.flac
#  extracting: train_data/1081/125237/1081-125237-0087.flac
#  extracting: train_data/1081/125237/1081-125237-0094.flac
#  extracting: train_data/1081/125237/1081-125237-0095.flac
#  extracting: train_data/1081/125237/1081-125237-0102.flac
#  extracting: train_data/1081/125237/1081-125237-0105.flac
#  extracting: train_data/1081/125237/1081-125237-0113.flac
#  extracting: train_data/1081/128618/1081-128618-0000.flac
#  extracting: train_data/1081/128618/1081-128618-0006.flac
#  extracting: train_data/1081/128618/1081-128618-0010.flac
#  extracting: train_data/1081/128618/1081-128618-0012.flac
#  extracting: train_data/1081/128618/1081-128618-0013.flac
#  extracting: train_data/1088/129236/1088-129236-0001.flac
#  extracting: train_data/1088/129236/1088-129236-0007.flac
#  extracting: train_data/1088/129236/1088-129236-0011.flac
#  extracting: train_data/118/121721/118-121721-0010.flac
#  extracting: train_data/118/121721/118-121721-0012.flac
#  extracting: train_data/118/121721/118-121721-0013.flac
#  extracting: train_data/118/121721/118-121721-0020.flac
#  extracting: train_data/118/121721/118-121721-0025.flac
#  extracting: train_data/118/124588/118-124588-0000.flac
#  extracting: train_data/118/124588/118-124588-0013.flac
#  extracting: train_data/118/124588/118-124588-0017.flac
#  extracting: train_data/118/124588/118-124588-0018.flac
#  extracting: train_data/118/124588/118-124588-0019.flac
#  extracting: train_data/118/47824/118-47824-0001.flac
#  extracting: train_data/118/47824/118-47824-0002.flac
#  extracting: train_data/118/47824/118-47824-0004.flac
#  extracting: train_data/118/47824/118-47824-0006.flac
#  extracting: train_data/118/47824/118-47824-0008.flac
#  extracting: train_data/118/47824/118-47824-0011.flac
#  extracting: train_data/118/47824/118-47824-0014.flac
#  extracting: train_data/118/47824/118-47824-0015.flac
#  extracting: train_data/118/47824/118-47824-0023.flac
#  extracting: train_data/118/47824/118-47824-0026.flac
#  extracting: train_data/118/47824/118-47824-0034.flac
#  extracting: train_data/118/47824/118-47824-0038.flac
#  extracting: train_data/118/47824/118-47824-0040.flac
#  extracting: train_data/118/47824/118-47824-0047.flac
#  extracting: train_data/118/47824/118-47824-0061.flac
#  extracting: train_data/118/47824/118-47824-0062.flac
#  extracting: train_data/118/47824/118-47824-0073.flac
#  extracting: train_data/118/47824/118-47824-0081.flac
#  extracting: train_data/118/47824/118-47824-0085.flac
#  extracting: train_data/125/121124/125-121124-0000.flac
#  extracting: train_data/125/121124/125-121124-0002.flac
#  extracting: train_data/125/121124/125-121124-0008.flac
#  extracting: train_data/125/121124/125-121124-0011.flac
#  extracting: train_data/125/121124/125-121124-0014.flac
#  extracting: train_data/125/121124/125-121124-0025.flac
#  extracting: train_data/125/121124/125-121124-0031.flac
#  extracting: train_data/125/121124/125-121124-0039.flac
#  extracting: train_data/125/121124/125-121124-0047.flac
#  extracting: train_data/125/121124/125-121124-0049.flac
#  extracting: train_data/125/121124/125-121124-0055.flac
#  extracting: train_data/125/121124/125-121124-0057.flac
#  extracting: train_data/125/121124/125-121124-0062.flac
#  extracting: train_data/125/121124/125-121124-0066.flac
#  extracting: train_data/125/121124/125-121124-0068.flac
#  extracting: train_data/125/121124/125-121124-0070.flac
#  extracting: train_data/125/121124/125-121124-0078.flac
#  extracting: train_data/125/121124/125-121124-0083.flac
#  extracting: train_data/125/121124/125-121124-0084.flac
#  extracting: train_data/125/121124/125-121124-0086.flac
#  extracting: train_data/125/121342/125-121342-0002.flac
#  extracting: train_data/125/121342/125-121342-0003.flac
#  extracting: train_data/125/121342/125-121342-0008.flac
#  extracting: train_data/125/121342/125-121342-0010.flac
#  extracting: train_data/125/121342/125-121342-0016.flac
#  extracting: train_data/125/121342/125-121342-0018.flac
#  extracting: train_data/125/121342/125-121342-0027.flac
#  extracting: train_data/125/121342/125-121342-0028.flac
#  extracting: train_data/125/121342/125-121342-0030.flac
#  extracting: train_data/125/121342/125-121342-0032.flac
#  extracting: train_data/125/121342/125-121342-0037.flac
#  extracting: train_data/125/121342/125-121342-0038.flac
#  extracting: train_data/125/121342/125-121342-0043.flac
#  extracting: train_data/125/121342/125-121342-0047.flac
#  extracting: train_data/125/121342/125-121342-0048.flac
#  extracting: train_data/1594/135914/1594-135914-0001.flac
#  extracting: train_data/1594/135914/1594-135914-0007.flac
#  extracting: train_data/1594/135914/1594-135914-0010.flac
#  extracting: train_data/1594/135914/1594-135914-0017.flac
#  extracting: train_data/1594/135914/1594-135914-0019.flac
#  extracting: train_data/1594/135914/1594-135914-0021.flac
#  extracting: train_data/1594/135914/1594-135914-0027.flac
#  extracting: train_data/1594/135914/1594-135914-0028.flac
#  extracting: train_data/1594/135914/1594-135914-0029.flac
#  extracting: train_data/1594/135914/1594-135914-0032.flac
#  extracting: train_data/1594/135914/1594-135914-0039.flac
#  extracting: train_data/1594/135914/1594-135914-0045.flac
#  extracting: train_data/1594/135914/1594-135914-0048.flac
#  extracting: train_data/1594/135914/1594-135914-0058.flac
#  extracting: train_data/1594/135914/1594-135914-0060.flac
#  extracting: train_data/1594/135914/1594-135914-0063.flac
#  extracting: train_data/1594/135914/1594-135914-0072.flac
#  extracting: train_data/1594/135914/1594-135914-0075.flac
#  extracting: train_data/1594/135914/1594-135914-0076.flac
#  extracting: train_data/1594/135914/1594-135914-0085.flac
#  extracting: train_data/1594/135914/1594-135914-0090.flac
#  extracting: train_data/1594/135914/1594-135914-0092.flac
#  extracting: train_data/1594/135914/1594-135914-0093.flac
#  extracting: train_data/1594/135914/1594-135914-0094.flac
#  extracting: train_data/1594/135914/1594-135914-0098.flac
#  extracting: train_data/1594/135914/1594-135914-0104.flac
#  extracting: train_data/1594/135914/1594-135914-0110.flac
#  extracting: train_data/1594/135914/1594-135914-0118.flac
#  extracting: train_data/1594/135914/1594-135914-0121.flac
#  extracting: train_data/1594/135914/1594-135914-0126.flac
#  extracting: train_data/1594/135914/1594-135914-0128.flac
#  extracting: train_data/1723/141149/1723-141149-0001.flac
#  extracting: train_data/1723/141149/1723-141149-0005.flac
#  extracting: train_data/1723/141149/1723-141149-0007.flac
#  extracting: train_data/1723/141149/1723-141149-0009.flac
#  extracting: train_data/1723/141149/1723-141149-0014.flac
#  extracting: train_data/1723/141149/1723-141149-0018.flac
#  extracting: train_data/1723/141149/1723-141149-0022.flac
#  extracting: train_data/1723/141149/1723-141149-0033.flac
#  extracting: train_data/1723/141149/1723-141149-0037.flac
#  extracting: train_data/1723/141149/1723-141149-0039.flac
#  extracting: train_data/1723/141149/1723-141149-0046.flac
#  extracting: train_data/1723/141149/1723-141149-0050.flac
#  extracting: train_data/1723/141149/1723-141149-0052.flac
#  extracting: train_data/1723/141149/1723-141149-0061.flac
#  extracting: train_data/1723/141149/1723-141149-0062.flac
#  extracting: train_data/1723/141149/1723-141149-0067.flac
#  extracting: train_data/1723/141149/1723-141149-0072.flac
#  extracting: train_data/1723/141149/1723-141149-0082.flac
#  extracting: train_data/1723/141149/1723-141149-0090.flac
#  extracting: train_data/1723/141149/1723-141149-0091.flac
#  extracting: train_data/1723/141149/1723-141149-0099.flac
#  extracting: train_data/1723/141149/1723-141149-0103.flac
#  extracting: train_data/1723/141149/1723-141149-0106.flac
#  extracting: train_data/1723/141149/1723-141149-0107.flac
#  extracting: train_data/1723/141149/1723-141149-0110.flac
#  extracting: train_data/1723/141149/1723-141149-0111.flac
#  extracting: train_data/196/122150/196-122150-0002.flac
#  extracting: train_data/196/122150/196-122150-0004.flac
#  extracting: train_data/196/122150/196-122150-0013.flac
#  extracting: train_data/196/122150/196-122150-0027.flac
#  extracting: train_data/196/122150/196-122150-0029.flac
#  extracting: train_data/196/122150/196-122150-0039.flac
#  extracting: train_data/196/122152/196-122152-0000.flac
#  extracting: train_data/196/122152/196-122152-0008.flac
#  extracting: train_data/196/122152/196-122152-0010.flac
#  extracting: train_data/196/122152/196-122152-0015.flac
#  extracting: train_data/196/122152/196-122152-0016.flac
#  extracting: train_data/196/122152/196-122152-0018.flac
#  extracting: train_data/196/122152/196-122152-0021.flac
#  extracting: train_data/196/122152/196-122152-0022.flac
#  extracting: train_data/196/122152/196-122152-0024.flac
#  extracting: train_data/196/122152/196-122152-0026.flac
#  extracting: train_data/196/122152/196-122152-0030.flac
#  extracting: train_data/196/122152/196-122152-0031.flac
#  extracting: train_data/196/122159/196-122159-0001.flac
#  extracting: train_data/196/122159/196-122159-0003.flac
#  extracting: train_data/196/122159/196-122159-0004.flac
#  extracting: train_data/196/122159/196-122159-0007.flac
#  extracting: train_data/196/122159/196-122159-0018.flac
#  extracting: train_data/196/122159/196-122159-0022.flac
#  extracting: train_data/196/122159/196-122159-0025.flac
#  extracting: train_data/196/122159/196-122159-0030.flac
#  extracting: train_data/2002/139469/2002-139469-0000.flac
#  extracting: train_data/2002/139469/2002-139469-0005.flac
#  extracting: train_data/2002/139469/2002-139469-0006.flac
#  extracting: train_data/2002/139469/2002-139469-0008.flac
#  extracting: train_data/2002/139469/2002-139469-0010.flac
#  extracting: train_data/2002/139469/2002-139469-0012.flac
#  extracting: train_data/2002/139469/2002-139469-0014.flac
#  extracting: train_data/2002/139469/2002-139469-0024.flac
#  extracting: train_data/2002/139469/2002-139469-0029.flac
#  extracting: train_data/2002/139469/2002-139469-0032.flac
#  extracting: train_data/2002/139469/2002-139469-0039.flac
#  extracting: train_data/2002/139469/2002-139469-0040.flac
#  extracting: train_data/2002/139469/2002-139469-0042.flac
#  extracting: train_data/2002/139469/2002-139469-0047.flac
#  extracting: train_data/2002/139469/2002-139469-0052.flac
#  extracting: train_data/2002/139469/2002-139469-0054.flac
#  extracting: train_data/2002/139469/2002-139469-0055.flac
#  extracting: train_data/2002/139469/2002-139469-0059.flac
#  extracting: train_data/2002/139469/2002-139469-0065.flac
#  extracting: train_data/2002/139469/2002-139469-0072.flac
#  extracting: train_data/2002/139469/2002-139469-0077.flac
#  extracting: train_data/2002/139469/2002-139469-0081.flac
#  extracting: train_data/2002/139469/2002-139469-0086.flac
#  extracting: train_data/2002/139469/2002-139469-0090.flac
#  extracting: train_data/2002/139469/2002-139469-0096.flac
#  extracting: train_data/2002/139469/2002-139469-0097.flac
#  extracting: train_data/2002/139469/2002-139469-0100.flac
#  extracting: train_data/2002/139469/2002-139469-0112.flac
#  extracting: train_data/2002/139469/2002-139469-0114.flac
#  extracting: train_data/201/122255/201-122255-0006.flac
#  extracting: train_data/201/122255/201-122255-0012.flac
#  extracting: train_data/201/122255/201-122255-0020.flac
#  extracting: train_data/201/122255/201-122255-0042.flac
#  extracting: train_data/201/127786/201-127786-0004.flac
#  extracting: train_data/201/127786/201-127786-0015.flac
#  extracting: train_data/201/127786/201-127786-0017.flac
#  extracting: train_data/201/127786/201-127786-0019.flac
#  extracting: train_data/201/127786/201-127786-0021.flac
#  extracting: train_data/201/127786/201-127786-0025.flac
#  extracting: train_data/201/127786/201-127786-0026.flac
#  extracting: train_data/201/127786/201-127786-0033.flac
#  extracting: train_data/201/127786/201-127786-0035.flac
#  extracting: train_data/201/127786/201-127786-0038.flac
#  extracting: train_data/201/127786/201-127786-0041.flac
#  extracting: train_data/201/127786/201-127786-0042.flac
#  extracting: train_data/201/127786/201-127786-0045.flac
#  extracting: train_data/201/127786/201-127786-0048.flac
#  extracting: train_data/201/127786/201-127786-0050.flac
#  extracting: train_data/201/127786/201-127786-0051.flac
#  extracting: train_data/201/127786/201-127786-0059.flac
#  extracting: train_data/201/127786/201-127786-0062.flac
#  extracting: train_data/201/127786/201-127786-0066.flac
#  extracting: train_data/201/127786/201-127786-0069.flac
#  extracting: train_data/201/127786/201-127786-0070.flac
#  extracting: train_data/201/127786/201-127786-0071.flac
#  extracting: train_data/201/127786/201-127786-0073.flac
#  extracting: train_data/201/127786/201-127786-0077.flac
#  extracting: train_data/201/127786/201-127786-0078.flac
#  extracting: train_data/2159/179154/2159-179154-0003.flac
#  extracting: train_data/2159/179154/2159-179154-0004.flac
#  extracting: train_data/2159/179154/2159-179154-0007.flac
#  extracting: train_data/2159/179154/2159-179154-0008.flac
#  extracting: train_data/2159/179154/2159-179154-0011.flac
#  extracting: train_data/2159/179154/2159-179154-0013.flac
#  extracting: train_data/2159/179154/2159-179154-0024.flac
#  extracting: train_data/2159/179154/2159-179154-0033.flac
#  extracting: train_data/2159/179154/2159-179154-0034.flac
#  extracting: train_data/2159/179156/2159-179156-0001.flac
#  extracting: train_data/2159/179156/2159-179156-0005.flac
#  extracting: train_data/2159/179156/2159-179156-0006.flac
#  extracting: train_data/2159/179156/2159-179156-0011.flac
#  extracting: train_data/2159/179156/2159-179156-0015.flac
#  extracting: train_data/2159/179156/2159-179156-0027.flac
#  extracting: train_data/2159/179156/2159-179156-0031.flac
#  extracting: train_data/2159/179156/2159-179156-0032.flac
#  extracting: train_data/2159/179156/2159-179156-0035.flac
#  extracting: train_data/2159/179157/2159-179157-0002.flac
#  extracting: train_data/2159/179157/2159-179157-0004.flac
#  extracting: train_data/2159/179157/2159-179157-0005.flac
#  extracting: train_data/2159/179157/2159-179157-0006.flac
#  extracting: train_data/2159/179157/2159-179157-0009.flac
#  extracting: train_data/2159/179157/2159-179157-0013.flac
#  extracting: train_data/2159/179157/2159-179157-0014.flac
#  extracting: train_data/2159/179157/2159-179157-0016.flac
#  extracting: train_data/2159/179157/2159-179157-0022.flac
#  extracting: train_data/2159/179157/2159-179157-0023.flac
#  extracting: train_data/2182/150130/2182-150130-0005.flac
#  extracting: train_data/2182/150130/2182-150130-0006.flac
#  extracting: train_data/2182/150130/2182-150130-0012.flac
#  extracting: train_data/2182/150130/2182-150130-0013.flac
#  extracting: train_data/2182/150130/2182-150130-0014.flac
#  extracting: train_data/2182/150130/2182-150130-0016.flac
#  extracting: train_data/2182/150130/2182-150130-0024.flac
#  extracting: train_data/2182/150130/2182-150130-0030.flac
#  extracting: train_data/2182/181173/2182-181173-0003.flac
#  extracting: train_data/2182/181173/2182-181173-0022.flac
#  extracting: train_data/2182/181173/2182-181173-0024.flac
#  extracting: train_data/2182/181173/2182-181173-0025.flac
#  extracting: train_data/2182/181173/2182-181173-0027.flac
#  extracting: train_data/2182/181173/2182-181173-0029.flac
#  extracting: train_data/2182/181173/2182-181173-0031.flac
#  extracting: train_data/2182/181173/2182-181173-0033.flac
#  extracting: train_data/2182/181183/2182-181183-0007.flac
#  extracting: train_data/2182/181183/2182-181183-0012.flac
#  extracting: train_data/2182/181183/2182-181183-0020.flac
#  extracting: train_data/2182/181183/2182-181183-0022.flac
#  extracting: train_data/2182/181183/2182-181183-0026.flac
#  extracting: train_data/2182/181183/2182-181183-0029.flac
#  extracting: train_data/2182/181183/2182-181183-0031.flac
#  extracting: train_data/2182/181183/2182-181183-0033.flac
#  extracting: train_data/2182/181183/2182-181183-0034.flac
#  extracting: train_data/2196/170151/2196-170151-0013.flac
#  extracting: train_data/2196/170151/2196-170151-0015.flac
#  extracting: train_data/2196/170151/2196-170151-0021.flac
#  extracting: train_data/2196/170151/2196-170151-0023.flac
#  extracting: train_data/2196/170379/2196-170379-0001.flac
#  extracting: train_data/2196/170379/2196-170379-0011.flac
#  extracting: train_data/2196/170379/2196-170379-0012.flac
#  extracting: train_data/2196/170379/2196-170379-0013.flac
#  extracting: train_data/2196/170379/2196-170379-0017.flac
#  extracting: train_data/2196/170379/2196-170379-0019.flac
#  extracting: train_data/2196/170379/2196-170379-0023.flac
#  extracting: train_data/2196/170379/2196-170379-0030.flac
#  extracting: train_data/2196/170379/2196-170379-0032.flac
#  extracting: train_data/2196/170379/2196-170379-0034.flac
#  extracting: train_data/2196/174172/2196-174172-0007.flac
#  extracting: train_data/2196/174172/2196-174172-0010.flac
#  extracting: train_data/2196/174172/2196-174172-0014.flac
#  extracting: train_data/2196/174172/2196-174172-0016.flac
#  extracting: train_data/2196/174172/2196-174172-0018.flac
#  extracting: train_data/2196/174172/2196-174172-0019.flac
#  extracting: train_data/2196/174172/2196-174172-0021.flac
#  extracting: train_data/2196/174172/2196-174172-0022.flac
#  extracting: train_data/2196/174172/2196-174172-0030.flac
#  extracting: train_data/2196/174172/2196-174172-0032.flac
#  extracting: train_data/2196/174172/2196-174172-0037.flac
#  extracting: train_data/374/180299/374-180299-0045.flac
#  extracting: train_data/3983/5331/3983-5331-0004.flac
#  extracting: train_data/3983/5331/3983-5331-0005.flac
#  extracting: train_data/3983/5331/3983-5331-0006.flac
#  extracting: train_data/3983/5331/3983-5331-0007.flac
#  extracting: train_data/3983/5331/3983-5331-0011.flac
#  extracting: train_data/3983/5331/3983-5331-0030.flac
#  extracting: train_data/3983/5331/3983-5331-0032.flac
#  extracting: train_data/3983/5331/3983-5331-0034.flac
#  extracting: train_data/3983/5331/3983-5331-0044.flac
#  extracting: train_data/3983/5331/3983-5331-0046.flac
#  extracting: train_data/3983/5331/3983-5331-0050.flac
#  extracting: train_data/3983/5331/3983-5331-0053.flac
#  extracting: train_data/3983/5371/3983-5371-0003.flac
#  extracting: train_data/3983/5371/3983-5371-0006.flac
#  extracting: train_data/3983/5371/3983-5371-0008.flac
#  extracting: train_data/3983/5371/3983-5371-0017.flac
#  extracting: train_data/3983/5371/3983-5371-0019.flac
#  extracting: train_data/3983/5371/3983-5371-0022.flac
#  extracting: train_data/3983/5371/3983-5371-0026.flac
#  extracting: train_data/3983/5371/3983-5371-0029.flac
#  extracting: train_data/3983/5371/3983-5371-0030.flac
#  extracting: train_data/3983/5371/3983-5371-0043.flac
#  extracting: train_data/3983/5371/3983-5371-0044.flac
#  extracting: train_data/3983/5371/3983-5371-0052.flac
#  extracting: train_data/3983/5371/3983-5371-0057.flac
#  extracting: train_data/3983/5371/3983-5371-0058.flac
#  extracting: train_data/40/121026/40-121026-0001.flac
#  extracting: train_data/40/121026/40-121026-0006.flac
#  extracting: train_data/40/121026/40-121026-0008.flac
#  extracting: train_data/40/121026/40-121026-0011.flac
#  extracting: train_data/40/121026/40-121026-0012.flac
#  extracting: train_data/40/121026/40-121026-0013.flac
#  extracting: train_data/40/121026/40-121026-0022.flac
#  extracting: train_data/40/121026/40-121026-0025.flac
#  extracting: train_data/40/121026/40-121026-0026.flac
#  extracting: train_data/40/121026/40-121026-0028.flac
#  extracting: train_data/40/121026/40-121026-0031.flac
#  extracting: train_data/40/121026/40-121026-0036.flac
#  extracting: train_data/40/121026/40-121026-0038.flac
#  extracting: train_data/40/222/40-222-0008.flac
#  extracting: train_data/40/222/40-222-0011.flac
#  extracting: train_data/40/222/40-222-0015.flac
#  extracting: train_data/40/222/40-222-0018.flac
#  extracting: train_data/40/222/40-222-0019.flac
#  extracting: train_data/40/222/40-222-0030.flac
#  extracting: train_data/40/222/40-222-0031.flac
#  extracting: train_data/40/222/40-222-0032.flac
#  extracting: train_data/40/222/40-222-0033.flac
#  extracting: train_data/40/222/40-222-0036.flac
#  extracting: train_data/40/222/40-222-0039.flac
#  extracting: train_data/40/222/40-222-0047.flac
#  extracting: train_data/40/222/40-222-0053.flac
#  extracting: train_data/40/222/40-222-0055.flac
#  extracting: train_data/40/222/40-222-0061.flac
#  extracting: train_data/40/222/40-222-0067.flac
#  extracting: train_data/4267/287369/4267-287369-0018.flac
#  extracting: train_data/4267/287369/4267-287369-0022.flac
#  extracting: train_data/4267/287369/4267-287369-0028.flac
#  extracting: train_data/4267/287369/4267-287369-0030.flac
#  extracting: train_data/4267/287369/4267-287369-0034.flac
#  extracting: train_data/4267/72637/4267-72637-0000.flac
#  extracting: train_data/4267/72637/4267-72637-0001.flac
#  extracting: train_data/4267/72637/4267-72637-0014.flac
#  extracting: train_data/4267/72637/4267-72637-0017.flac
#  extracting: train_data/4267/72637/4267-72637-0022.flac
#  extracting: train_data/4267/72637/4267-72637-0025.flac
#  extracting: train_data/4267/72637/4267-72637-0029.flac
#  extracting: train_data/4267/72637/4267-72637-0031.flac
#  extracting: train_data/4267/72637/4267-72637-0033.flac
#  extracting: train_data/4267/72637/4267-72637-0034.flac
#  extracting: train_data/4267/78186/4267-78186-0000.flac
#  extracting: train_data/4267/78186/4267-78186-0002.flac
#  extracting: train_data/4267/78186/4267-78186-0011.flac
#  extracting: train_data/4267/78186/4267-78186-0013.flac
#  extracting: train_data/4267/78186/4267-78186-0017.flac
#  extracting: train_data/4267/78186/4267-78186-0018.flac
#  extracting: train_data/4267/78186/4267-78186-0019.flac
#  extracting: train_data/4267/78186/4267-78186-0022.flac
#  extracting: train_data/4267/78186/4267-78186-0024.flac
#  extracting: train_data/4267/78186/4267-78186-0035.flac
#  extracting: train_data/4362/15663/4362-15663-0001.flac
#  extracting: train_data/4362/15663/4362-15663-0007.flac
#  extracting: train_data/4362/15663/4362-15663-0008.flac
#  extracting: train_data/4362/15663/4362-15663-0012.flac
#  extracting: train_data/4362/15663/4362-15663-0024.flac
#  extracting: train_data/4362/15663/4362-15663-0026.flac
#  extracting: train_data/4362/15663/4362-15663-0027.flac
#  extracting: train_data/4362/15663/4362-15663-0028.flac
#  extracting: train_data/4362/15663/4362-15663-0032.flac
#  extracting: train_data/4362/15663/4362-15663-0034.flac
#  extracting: train_data/4362/15663/4362-15663-0052.flac
#  extracting: train_data/4362/15663/4362-15663-0055.flac
#  extracting: train_data/4362/15663/4362-15663-0058.flac
#  extracting: train_data/4362/15663/4362-15663-0060.flac
#  extracting: train_data/4362/15663/4362-15663-0063.flac
#  extracting: train_data/4362/15663/4362-15663-0064.flac
#  extracting: train_data/4362/15663/4362-15663-0070.flac
#  extracting: train_data/4362/15663/4362-15663-0073.flac
#  extracting: train_data/4362/15663/4362-15663-0076.flac
#  extracting: train_data/4362/15663/4362-15663-0080.flac
#  extracting: train_data/4362/15663/4362-15663-0082.flac
#  extracting: train_data/4362/15663/4362-15663-0084.flac
#  extracting: train_data/4362/15663/4362-15663-0091.flac
#  extracting: train_data/4362/15663/4362-15663-0092.flac
#  extracting: train_data/4362/15663/4362-15663-0095.flac
#  extracting: train_data/4362/15663/4362-15663-0099.flac
#  extracting: train_data/4406/16882/4406-16882-0010.flac
#  extracting: train_data/4406/16882/4406-16882-0012.flac
#  extracting: train_data/4406/16882/4406-16882-0017.flac
#  extracting: train_data/4406/16882/4406-16882-0020.flac
#  extracting: train_data/4406/16882/4406-16882-0024.flac
#  extracting: train_data/4406/16882/4406-16882-0026.flac
#  extracting: train_data/4406/16882/4406-16882-0031.flac
#  extracting: train_data/4406/16882/4406-16882-0035.flac
#  extracting: train_data/4406/16882/4406-16882-0037.flac
#  extracting: train_data/4406/16882/4406-16882-0038.flac
#  extracting: train_data/4406/16882/4406-16882-0039.flac
#  extracting: train_data/4406/16882/4406-16882-0049.flac
#  extracting: train_data/4406/16882/4406-16882-0054.flac
#  extracting: train_data/4406/16882/4406-16882-0055.flac
#  extracting: train_data/4406/16882/4406-16882-0058.flac
#  extracting: train_data/4406/16882/4406-16882-0067.flac
#  extracting: train_data/4406/16883/4406-16883-0006.flac
#  extracting: train_data/4406/16883/4406-16883-0011.flac
#  extracting: train_data/4406/16883/4406-16883-0012.flac
#  extracting: train_data/4406/16883/4406-16883-0016.flac
#  extracting: train_data/4406/16883/4406-16883-0032.flac
#  extracting: train_data/4406/16883/4406-16883-0033.flac
#  extracting: train_data/4406/16883/4406-16883-0036.flac
#  extracting: train_data/4406/16883/4406-16883-0039.flac
#  extracting: train_data/4406/16883/4406-16883-0045.flac
#  extracting: train_data/4406/16883/4406-16883-0047.flac
#  extracting: train_data/4406/16883/4406-16883-0053.flac
#  extracting: train_data/4406/16883/4406-16883-0059.flac
#  extracting: train_data/4406/16883/4406-16883-0060.flac
#  extracting: train_data/441/128982/441-128982-0002.flac
#  extracting: train_data/441/128982/441-128982-0003.flac
#  extracting: train_data/441/128982/441-128982-0006.flac
#  extracting: train_data/441/128982/441-128982-0012.flac
#  extracting: train_data/441/128982/441-128982-0015.flac
#  extracting: train_data/441/128982/441-128982-0016.flac
#  extracting: train_data/441/128982/441-128982-0025.flac
#  extracting: train_data/441/128982/441-128982-0032.flac
#  extracting: train_data/441/128982/441-128982-0036.flac
#  extracting: train_data/441/128988/441-128988-0002.flac
#  extracting: train_data/441/128988/441-128988-0003.flac
#  extracting: train_data/441/128988/441-128988-0007.flac
#  extracting: train_data/441/128988/441-128988-0009.flac
#  extracting: train_data/441/128988/441-128988-0015.flac
#  extracting: train_data/441/128988/441-128988-0018.flac
#  extracting: train_data/441/128988/441-128988-0023.flac
#  extracting: train_data/441/128988/441-128988-0027.flac
#  extracting: train_data/441/130108/441-130108-0001.flac
#  extracting: train_data/441/130108/441-130108-0003.flac
#  extracting: train_data/441/130108/441-130108-0004.flac
#  extracting: train_data/441/130108/441-130108-0005.flac
#  extracting: train_data/441/130108/441-130108-0017.flac
#  extracting: train_data/441/130108/441-130108-0019.flac
#  extracting: train_data/441/130108/441-130108-0025.flac
#  extracting: train_data/441/130108/441-130108-0027.flac
#  extracting: train_data/441/130108/441-130108-0034.flac
#  extracting: train_data/441/130108/441-130108-0039.flac
#  extracting: train_data/441/130108/441-130108-0041.flac
#  extracting: train_data/4441/76250/4441-76250-0000.flac
#  extracting: train_data/4441/76250/4441-76250-0002.flac
#  extracting: train_data/4441/76250/4441-76250-0008.flac
#  extracting: train_data/4441/76250/4441-76250-0011.flac
#  extracting: train_data/4441/76250/4441-76250-0025.flac
#  extracting: train_data/4441/76250/4441-76250-0032.flac
#  extracting: train_data/4441/76250/4441-76250-0033.flac
#  extracting: train_data/4441/76250/4441-76250-0038.flac
#  extracting: train_data/4441/76262/4441-76262-0001.flac
#  extracting: train_data/4441/76262/4441-76262-0003.flac
#  extracting: train_data/4441/76262/4441-76262-0007.flac
#  extracting: train_data/4441/76262/4441-76262-0008.flac
#  extracting: train_data/4441/76262/4441-76262-0015.flac
#  extracting: train_data/4441/76262/4441-76262-0017.flac
#  extracting: train_data/4441/76262/4441-76262-0019.flac
#  extracting: train_data/4441/76262/4441-76262-0020.flac
#  extracting: train_data/4441/76262/4441-76262-0033.flac
#  extracting: train_data/4441/76262/4441-76262-0034.flac
#  extracting: train_data/4441/76262/4441-76262-0036.flac
#  extracting: train_data/4441/76263/4441-76263-0000.flac
#  extracting: train_data/4441/76263/4441-76263-0002.flac
#  extracting: train_data/4441/76263/4441-76263-0013.flac
#  extracting: train_data/4441/76263/4441-76263-0017.flac
#  extracting: train_data/4441/76263/4441-76263-0020.flac
#  extracting: train_data/4441/76263/4441-76263-0024.flac
#  extracting: train_data/4441/76263/4441-76263-0034.flac
#  extracting: train_data/4441/76263/4441-76263-0044.flac
#  extracting: train_data/4441/76263/4441-76263-0045.flac
#  extracting: train_data/460/172357/460-172357-0001.flac
#  extracting: train_data/460/172357/460-172357-0005.flac
#  extracting: train_data/460/172357/460-172357-0010.flac
#  extracting: train_data/460/172357/460-172357-0013.flac
#  extracting: train_data/460/172357/460-172357-0015.flac
#  extracting: train_data/460/172357/460-172357-0019.flac
#  extracting: train_data/460/172357/460-172357-0020.flac
#  extracting: train_data/460/172357/460-172357-0022.flac
#  extracting: train_data/460/172359/460-172359-0000.flac
#  extracting: train_data/460/172359/460-172359-0005.flac
#  extracting: train_data/460/172359/460-172359-0010.flac
#  extracting: train_data/460/172359/460-172359-0012.flac
#  extracting: train_data/460/172359/460-172359-0017.flac
#  extracting: train_data/460/172359/460-172359-0022.flac
#  extracting: train_data/460/172359/460-172359-0025.flac
#  extracting: train_data/460/172359/460-172359-0035.flac
#  extracting: train_data/460/172359/460-172359-0039.flac
#  extracting: train_data/460/172359/460-172359-0047.flac
#  extracting: train_data/460/172359/460-172359-0048.flac
#  extracting: train_data/460/172359/460-172359-0050.flac
#  extracting: train_data/460/172359/460-172359-0061.flac
#  extracting: train_data/460/172359/460-172359-0062.flac
#  extracting: train_data/460/172359/460-172359-0063.flac
#  extracting: train_data/460/172359/460-172359-0070.flac
#  extracting: train_data/460/172359/460-172359-0073.flac
#  extracting: train_data/460/172359/460-172359-0075.flac
#  extracting: train_data/460/172359/460-172359-0077.flac
#  extracting: train_data/460/172359/460-172359-0083.flac
#  extracting: train_data/460/172359/460-172359-0084.flac
#  extracting: train_data/460/172359/460-172359-0085.flac
#  extracting: train_data/460/172359/460-172359-0098.flac
#  extracting: train_data/4640/19187/4640-19187-0005.flac
#  extracting: train_data/4640/19187/4640-19187-0006.flac
#  extracting: train_data/4640/19187/4640-19187-0011.flac
#  extracting: train_data/4640/19187/4640-19187-0014.flac
#  extracting: train_data/4640/19187/4640-19187-0018.flac
#  extracting: train_data/4640/19187/4640-19187-0023.flac
#  extracting: train_data/4640/19187/4640-19187-0026.flac
#  extracting: train_data/4640/19187/4640-19187-0027.flac
#  extracting: train_data/4640/19187/4640-19187-0031.flac
#  extracting: train_data/4640/19187/4640-19187-0033.flac
#  extracting: train_data/4640/19187/4640-19187-0035.flac
#  extracting: train_data/4640/19188/4640-19188-0012.flac
#  extracting: train_data/4640/19188/4640-19188-0013.flac
#  extracting: train_data/4640/19188/4640-19188-0014.flac
#  extracting: train_data/4640/19188/4640-19188-0015.flac
#  extracting: train_data/4640/19188/4640-19188-0018.flac
#  extracting: train_data/4640/19188/4640-19188-0019.flac
#  extracting: train_data/4640/19188/4640-19188-0021.flac
#  extracting: train_data/4640/19188/4640-19188-0027.flac
#  extracting: train_data/4640/19188/4640-19188-0033.flac
#  extracting: train_data/4640/19189/4640-19189-0001.flac
#  extracting: train_data/4640/19189/4640-19189-0003.flac
#  extracting: train_data/4640/19189/4640-19189-0008.flac
#  extracting: train_data/4640/19189/4640-19189-0023.flac
#  extracting: train_data/4640/19189/4640-19189-0024.flac
#  extracting: train_data/4640/19189/4640-19189-0025.flac
#  extracting: train_data/4640/19189/4640-19189-0034.flac
#  extracting: train_data/4640/19189/4640-19189-0035.flac
#  extracting: train_data/4640/19189/4640-19189-0038.flac
#  extracting: train_data/4640/19189/4640-19189-0039.flac
#  extracting: train_data/4680/16026/4680-16026-0003.flac
#  extracting: train_data/4680/16026/4680-16026-0005.flac
#  extracting: train_data/4680/16026/4680-16026-0007.flac
#  extracting: train_data/4680/16026/4680-16026-0021.flac
#  extracting: train_data/4680/16026/4680-16026-0026.flac
#  extracting: train_data/4680/16026/4680-16026-0030.flac
#  extracting: train_data/4680/16026/4680-16026-0032.flac
#  extracting: train_data/4680/16026/4680-16026-0035.flac
#  extracting: train_data/4680/16026/4680-16026-0039.flac
#  extracting: train_data/4680/16041/4680-16041-0000.flac
#  extracting: train_data/4680/16041/4680-16041-0004.flac
#  extracting: train_data/4680/16041/4680-16041-0005.flac
#  extracting: train_data/4680/16041/4680-16041-0007.flac
#  extracting: train_data/4680/16041/4680-16041-0009.flac
#  extracting: train_data/4680/16041/4680-16041-0013.flac
#  extracting: train_data/4680/16041/4680-16041-0022.flac
#  extracting: train_data/4680/16041/4680-16041-0025.flac
#  extracting: train_data/4680/16041/4680-16041-0027.flac
#  extracting: train_data/4680/16041/4680-16041-0032.flac
#  extracting: train_data/4680/16041/4680-16041-0034.flac
#  extracting: train_data/4680/16041/4680-16041-0036.flac
#  extracting: train_data/4680/16042/4680-16042-0000.flac
# ...
#  extracting: val_data/1578/6379/1578-6379-0027.flac
#  extracting: val_data/1578/6379/1578-6379-0029.flac
#  extracting: val_data/1926/143879/1926-143879-0010.flac
#  extracting: val_data/1926/143879/1926-143879-0029.flac
#  extracting: val_data/1926/143879/1926-143879-0030.flac
#  extracting: val_data/1926/143879/1926-143879-0046.flac
#  extracting: val_data/1926/147979/1926-147979-0013.flac
#  extracting: val_data/1926/147979/1926-147979-0020.flac
#  extracting: val_data/1926/147987/1926-147987-0025.flac
#  extracting: val_data/211/122425/211-122425-0001.flac
#  extracting: val_data/211/122425/211-122425-0020.flac
#  extracting: val_data/211/122425/211-122425-0046.flac
#  extracting: val_data/211/122425/211-122425-0048.flac
#  extracting: val_data/211/122425/211-122425-0076.flac
#  extracting: val_data/211/122442/211-122442-0028.flac
#  extracting: val_data/211/122442/211-122442-0053.flac
#  extracting: val_data/211/122442/211-122442-0057.flac
#  extracting: val_data/211/122442/211-122442-0069.flac
#  extracting: val_data/211/122442/211-122442-0072.flac
#  extracting: val_data/2416/152137/2416-152137-0035.flac
#  extracting: val_data/2416/152139/2416-152139-0004.flac
#  extracting: val_data/2416/152139/2416-152139-0017.flac
#  extracting: val_data/2416/152139/2416-152139-0036.flac
#  extracting: val_data/2416/152139/2416-152139-0040.flac
#  extracting: val_data/2436/2476/2436-2476-0010.flac
#  extracting: val_data/2436/2476/2436-2476-0012.flac
#  extracting: val_data/2436/2476/2436-2476-0017.flac
#  extracting: val_data/2436/2477/2436-2477-0008.flac
#  extracting: val_data/2436/2477/2436-2477-0028.flac
#  extracting: val_data/2436/2477/2436-2477-0034.flac
#  extracting: val_data/2436/2481/2436-2481-0008.flac
#  extracting: val_data/2436/2481/2436-2481-0016.flac
#  extracting: val_data/248/130644/248-130644-0006.flac
#  extracting: val_data/248/130644/248-130644-0028.flac
#  extracting: val_data/248/130644/248-130644-0034.flac
#  extracting: val_data/248/130697/248-130697-0025.flac
#  extracting: val_data/248/130697/248-130697-0030.flac
#  extracting: val_data/248/130697/248-130697-0036.flac
#  extracting: val_data/2691/156745/2691-156745-0003.flac
#  extracting: val_data/2691/156745/2691-156745-0005.flac
#  extracting: val_data/2691/156745/2691-156745-0013.flac
#  extracting: val_data/2691/156745/2691-156745-0031.flac
#  extracting: val_data/2691/156750/2691-156750-0021.flac
#  extracting: val_data/2691/156755/2691-156755-0009.flac
#  extracting: val_data/2691/156755/2691-156755-0019.flac
#  extracting: val_data/2764/36616/2764-36616-0010.flac
#  extracting: val_data/2764/36616/2764-36616-0011.flac
#  extracting: val_data/2764/36617/2764-36617-0000.flac
#  extracting: val_data/2764/36617/2764-36617-0026.flac
#  extracting: val_data/2764/36619/2764-36619-0015.flac
#  extracting: val_data/2764/36619/2764-36619-0025.flac
#  extracting: val_data/2764/36619/2764-36619-0026.flac
#  extracting: val_data/2817/142371/2817-142371-0008.flac
#  extracting: val_data/2817/142371/2817-142371-0014.flac
#  extracting: val_data/2817/142371/2817-142371-0016.flac
#  extracting: val_data/2817/142371/2817-142371-0051.flac
#  extracting: val_data/2817/142380/2817-142380-0001.flac
#  extracting: val_data/2817/142380/2817-142380-0023.flac
#  extracting: val_data/2817/142380/2817-142380-0039.flac
#  extracting: val_data/2836/5354/2836-5354-0006.flac
#  extracting: val_data/2836/5354/2836-5354-0031.flac
#  extracting: val_data/2836/5354/2836-5354-0036.flac
#  extracting: val_data/2836/5354/2836-5354-0041.flac
#  extracting: val_data/2836/5354/2836-5354-0047.flac
#  extracting: val_data/3440/171009/3440-171009-0038.flac
#  extracting: val_data/3440/171009/3440-171009-0061.flac
#  extracting: val_data/3440/171009/3440-171009-0077.flac
#  extracting: val_data/3440/171009/3440-171009-0082.flac
#  extracting: val_data/3664/11714/3664-11714-0005.flac
#  extracting: val_data/3664/11714/3664-11714-0011.flac
#  extracting: val_data/3664/178366/3664-178366-0017.flac
#  extracting: val_data/3664/178366/3664-178366-0028.flac
#  extracting: val_data/3664/178366/3664-178366-0035.flac
#  extracting: val_data/3857/180923/3857-180923-0020.flac
#  extracting: val_data/3857/182315/3857-182315-0009.flac
#  extracting: val_data/3857/182315/3857-182315-0019.flac
#  extracting: val_data/3857/182317/3857-182317-0006.flac
#  extracting: val_data/3857/182317/3857-182317-0030.flac
#  extracting: val_data/3879/173592/3879-173592-0009.flac
#  extracting: val_data/3879/174923/3879-174923-0002.flac
#  extracting: val_data/3879/174923/3879-174923-0023.flac
#  extracting: val_data/3879/174923/3879-174923-0028.flac
#  extracting: val_data/3879/174923/3879-174923-0055.flac
#  extracting: val_data/4137/11701/4137-11701-0027.flac
#  extracting: val_data/4137/11701/4137-11701-0047.flac
#  extracting: val_data/4137/11702/4137-11702-0002.flac
#  extracting: val_data/4137/11702/4137-11702-0010.flac
#  extracting: val_data/4137/11702/4137-11702-0025.flac
#  extracting: val_data/4137/11702/4137-11702-0054.flac
#  extracting: val_data/4195/17507/4195-17507-0040.flac
#  extracting: val_data/4195/17507/4195-17507-0041.flac
#  extracting: val_data/4195/186236/4195-186236-0000.flac
#  extracting: val_data/4195/186236/4195-186236-0025.flac
#  extracting: val_data/4195/186237/4195-186237-0023.flac
#  extracting: val_data/4195/186237/4195-186237-0033.flac
#  extracting: val_data/4195/186238/4195-186238-0025.flac
#  extracting: val_data/4195/186238/4195-186238-0026.flac
#  extracting: val_data/426/122819/426-122819-0001.flac
#  extracting: val_data/426/122819/426-122819-0028.flac
#  extracting: val_data/426/122819/426-122819-0030.flac
#  extracting: val_data/426/122821/426-122821-0025.flac
#  extracting: val_data/426/122821/426-122821-0038.flac
#  extracting: val_data/4297/13006/4297-13006-0003.flac
#  extracting: val_data/4297/13006/4297-13006-0026.flac
#  extracting: val_data/4297/13006/4297-13006-0035.flac
#  extracting: val_data/4297/13006/4297-13006-0044.flac
#  extracting: val_data/4297/13009/4297-13009-0051.flac
#  extracting: val_data/446/123501/446-123501-0007.flac
#  extracting: val_data/446/123501/446-123501-0019.flac
#  extracting: val_data/446/123501/446-123501-0030.flac
#  extracting: val_data/446/123501/446-123501-0045.flac
#  extracting: val_data/446/123501/446-123501-0058.flac
#  extracting: val_data/446/123502/446-123502-0020.flac
#  extracting: val_data/446/123502/446-123502-0049.flac
#  extracting: val_data/4788/294466/4788-294466-0009.flac
#  extracting: val_data/4788/91208/4788-91208-0018.flac
#  extracting: val_data/4788/91208/4788-91208-0024.flac
#  extracting: val_data/4788/94904/4788-94904-0009.flac
#  extracting: val_data/4788/94904/4788-94904-0033.flac
#  extracting: val_data/481/123720/481-123720-0008.flac
#  extracting: val_data/7800/283492/7800-283492-0025.flac
#  extracting: val_data/7800/283493/7800-283493-0003.flac
#  extracting: val_data/8312/279790/8312-279790-0003.flac
#  extracting: val_data/8312/279790/8312-279790-0021.flac
#  extracting: val_data/8312/279791/8312-279791-0005.flac
#  extracting: val_data/8312/279791/8312-279791-0019.flac
#  extracting: val_data/8312/279791/8312-279791-0023.flac
#  extracting: val_data/8312/279791/8312-279791-0043.flac
#  extracting: val_data/8425/246962/8425-246962-0015.flac
#  extracting: val_data/8425/246962/8425-246962-0023.flac
#  extracting: val_data/8425/291444/8425-291444-0014.flac
#  extracting: val_data/8425/292520/8425-292520-0001.flac
#  extracting: val_data/8425/292520/8425-292520-0024.flac
#  extracting: val_data/8465/246940/8465-246940-0010.flac
#  extracting: val_data/8465/246942/8465-246942-0010.flac
#  extracting: val_data/8465/246942/8465-246942-0012.flac
#  extracting: val_data/8465/246942/8465-246942-0013.flac
#  extracting: val_data/8465/246943/8465-246943-0021.flac
#  extracting: val_data/8465/246947/8465-246947-0000.flac
#  extracting: val_data/8465/246947/8465-246947-0015.flac
#  extracting: val_data/8468/286673/8468-286673-0006.flac
#  extracting: val_data/8468/294887/8468-294887-0025.flac
#  extracting: val_data/8468/294887/8468-294887-0027.flac
#  extracting: val_data/8468/294887/8468-294887-0033.flac
#  extracting: val_data/8468/295198/8468-295198-0012.flac
#  extracting: val_data/8468/295198/8468-295198-0031.flac
#  extracting: val_data/8838/298545/8838-298545-0000.flac
#  extracting: val_data/8838/298546/8838-298546-0015.flac
#  extracting: val_data/8838/298546/8838-298546-0022.flac
#  extracting: val_data/8838/298546/8838-298546-0028.flac
#  extracting: val_data/8838/298546/8838-298546-0039.flac
#  extracting: val_data/887/123289/887-123289-0020.flac
#  extracting: val_data/887/123290/887-123290-0005.flac
#  extracting: val_data/887/123290/887-123290-0009.flac
#  extracting: val_data/887/123290/887-123290-0015.flac
#  extracting: val_data/887/123291/887-123291-0019.flac
#  extracting: val_data/887/123291/887-123291-0029.flac
#  extracting: val_data/887/123291/887-123291-0034.flac
#  extracting: val_data/89/218/89-218-0020.flac
#  extracting: val_data/89/218/89-218-0035.flac
#  extracting: val_data/89/218/89-218-0051.flac
#  extracting: val_data/89/219/89-219-0013.flac
#  extracting: val_data/89/219/89-219-0033.flac
#  extracting: val_data/89/219/89-219-0050.flac
#  extracting: val_data/909/131041/909-131041-0008.flac
#  extracting: val_data/909/131041/909-131041-0009.flac
#  extracting: val_data/909/131041/909-131041-0015.flac
#  extracting: val_data/909/131044/909-131044-0004.flac
#  extracting: val_data/909/131044/909-131044-0033.flac
# adc.json  sample_data  train_data.zip  val_data.zip
# gdrive	  train_data   val_data

# %%
# %cd /content
label_aligned  = drive.CreateFile({'id':'1bLuDkapGBERG_VYPS7fNZl5GXsQ9z3p2'})
label_aligned.GetContentFile('phone_data.zip')
# !unzip phone_data.zip
# Out:
# /content
# Archive:  phone_data.zip
#   inflating: converted_aligned_phones.txt
#    creating: __MACOSX/
#   inflating: __MACOSX/._converted_aligned_phones.txt

# %%
# %cd /content
# !mkdir per_data
es_aligned  = drive.CreateFile({'id':'1EnR-4zVXetYSYEMLGRWDSFhc0wmjIKmf'})
es_aligned.GetContentFile('per_data/train.zip')
es_aligned_val  = drive.CreateFile({'id':'1gLOPrWa_-9f_F8aXMasKyrm61rs11Slu'})
es_aligned_val.GetContentFile('per_data/val.zip')
es_phone_data = drive.CreateFile({'id':'19eScg1DijWzKHMQsHqCQm68aXt9lGE03'})
es_phone_data.GetContentFile('per_data/phones.txt')
# !mkdir per_data/train_es 
# !mkdir per_data/val_es
# !unzip per_data/train.zip -d per_data/train_es
# !unzip per_data/val.zip -d per_data/val_es
# Out:
# /content
# Archive:  per_data/train.zip
#  extracting: per_data/train_es/common_voice_es_18307013.mp3
#  extracting: per_data/train_es/common_voice_es_18309351.mp3
#  extracting: per_data/train_es/common_voice_es_18309354.mp3
#  extracting: per_data/train_es/common_voice_es_18309527.mp3
#  extracting: per_data/train_es/common_voice_es_18309528.mp3
#  extracting: per_data/train_es/common_voice_es_18309709.mp3
#  extracting: per_data/train_es/common_voice_es_18309711.mp3
#  extracting: per_data/train_es/common_voice_es_18309899.mp3
#  extracting: per_data/train_es/common_voice_es_18309900.mp3
#  extracting: per_data/train_es/common_voice_es_18309901.mp3
#  extracting: per_data/train_es/common_voice_es_18310105.mp3
#  extracting: per_data/train_es/common_voice_es_18310110.mp3
#  extracting: per_data/train_es/common_voice_es_18310112.mp3
#  extracting: per_data/train_es/common_voice_es_18311008.mp3
#  extracting: per_data/train_es/common_voice_es_18311009.mp3
#  extracting: per_data/train_es/common_voice_es_18311010.mp3
#  extracting: per_data/train_es/common_voice_es_18311019.mp3
#  extracting: per_data/train_es/common_voice_es_18311417.mp3
#  extracting: per_data/train_es/common_voice_es_18311418.mp3
#  extracting: per_data/train_es/common_voice_es_18311424.mp3
#  extracting: per_data/train_es/common_voice_es_18311426.mp3
#  extracting: per_data/train_es/common_voice_es_18311734.mp3
#  extracting: per_data/train_es/common_voice_es_18311735.mp3
#  extracting: per_data/train_es/common_voice_es_18311736.mp3
#  extracting: per_data/train_es/common_voice_es_18311737.mp3
#  extracting: per_data/train_es/common_voice_es_18311989.mp3
#  extracting: per_data/train_es/common_voice_es_18311990.mp3
#  extracting: per_data/train_es/common_voice_es_18311991.mp3
#  extracting: per_data/train_es/common_voice_es_18311992.mp3
#  extracting: per_data/train_es/common_voice_es_18312165.mp3
#  extracting: per_data/train_es/common_voice_es_18312166.mp3
#  extracting: per_data/train_es/common_voice_es_18312477.mp3
#  extracting: per_data/train_es/common_voice_es_18312482.mp3
#  extracting: per_data/train_es/common_voice_es_18312489.mp3
#  extracting: per_data/train_es/common_voice_es_18312753.mp3
#  extracting: per_data/train_es/common_voice_es_18312755.mp3
#  extracting: per_data/train_es/common_voice_es_18312756.mp3
#  extracting: per_data/train_es/common_voice_es_18314041.mp3
#  extracting: per_data/train_es/common_voice_es_18314042.mp3
#  extracting: per_data/train_es/common_voice_es_18314043.mp3
#  extracting: per_data/val_es/common_voice_es_18370479.mp3
#  extracting: per_data/val_es/common_voice_es_18370481.mp3
#  extracting: per_data/val_es/common_voice_es_18370868.mp3
#  extracting: per_data/val_es/common_voice_es_18370869.mp3
#  extracting: per_data/val_es/common_voice_es_18373058.mp3
#  extracting: per_data/val_es/common_voice_es_18373368.mp3
#  extracting: per_data/val_es/common_voice_es_18373370.mp3
#  extracting: per_data/val_es/common_voice_es_18383346.mp3
#  extracting: per_data/val_es/common_voice_es_18383348.mp3
#  extracting: per_data/val_es/common_voice_es_18383350.mp3
#  extracting: per_data/val_es/common_voice_es_18387129.mp3
#  extracting: per_data/val_es/common_voice_es_18387130.mp3
#  extracting: per_data/val_es/common_voice_es_18387427.mp3
#  extracting: per_data/val_es/common_voice_es_18391848.mp3
#  extracting: per_data/val_es/common_voice_es_18394785.mp3
#  extracting: per_data/val_es/common_voice_es_18394786.mp3
#  extracting: per_data/val_es/common_voice_es_18406558.mp3
#  extracting: per_data/val_es/common_voice_es_18413641.mp3
#  extracting: per_data/val_es/common_voice_es_18425698.mp3
#  extracting: per_data/val_es/common_voice_es_18425699.mp3
#  extracting: per_data/val_es/common_voice_es_18425700.mp3
#  extracting: per_data/val_es/common_voice_es_18425701.mp3
#  extracting: per_data/val_es/common_voice_es_18440791.mp3
#  extracting: per_data/val_es/common_voice_es_18440792.mp3
#  extracting: per_data/val_es/common_voice_es_18442067.mp3
#  extracting: per_data/val_es/common_voice_es_18442068.mp3
#  extracting: per_data/val_es/common_voice_es_18442987.mp3
#  extracting: per_data/val_es/common_voice_es_18449472.mp3
#  extracting: per_data/val_es/common_voice_es_18449473.mp3
#  extracting: per_data/val_es/common_voice_es_18456342.mp3
#  extracting: per_data/val_es/common_voice_es_18475978.mp3
#  extracting: per_data/val_es/common_voice_es_18475979.mp3
#  extracting: per_data/val_es/common_voice_es_18475980.mp3
#  extracting: per_data/val_es/common_voice_es_18479448.mp3
#  extracting: per_data/val_es/common_voice_es_18480462.mp3
#  extracting: per_data/val_es/common_voice_es_18480464.mp3
#  extracting: per_data/val_es/common_voice_es_18480465.mp3
#  extracting: per_data/val_es/common_voice_es_18480467.mp3
#  extracting: per_data/val_es/common_voice_es_18485811.mp3
#  extracting: per_data/val_es/common_voice_es_18487018.mp3
#  extracting: per_data/val_es/common_voice_es_18487396.mp3
#  extracting: per_data/val_es/common_voice_es_18493238.mp3
#  extracting: per_data/val_es/common_voice_es_18493858.mp3
#  extracting: per_data/val_es/common_voice_es_18493859.mp3
#  extracting: per_data/val_es/common_voice_es_18494196.mp3
#  extracting: per_data/val_es/common_voice_es_18494197.mp3
#  extracting: per_data/val_es/common_voice_es_18494198.mp3
#  extracting: per_data/val_es/common_voice_es_18494199.mp3
#  extracting: per_data/val_es/common_voice_es_18494200.mp3
#  extracting: per_data/val_es/common_voice_es_18497042.mp3
#  extracting: per_data/val_es/common_voice_es_18504156.mp3
#  extracting: per_data/val_es/common_voice_es_18509025.mp3
#  extracting: per_data/val_es/common_voice_es_18509026.mp3
#  extracting: per_data/val_es/common_voice_es_18509027.mp3
#  extracting: per_data/val_es/common_voice_es_18674075.mp3
#  extracting: per_data/val_es/common_voice_es_18676854.mp3
#  extracting: per_data/val_es/common_voice_es_18677527.mp3
#  extracting: per_data/val_es/common_voice_es_18677530.mp3
#  extracting: per_data/val_es/common_voice_es_18686510.mp3
#  extracting: per_data/val_es/common_voice_es_18686511.mp3
#  extracting: per_data/val_es/common_voice_es_18702134.mp3
#  extracting: per_data/val_es/common_voice_es_18702136.mp3
#  extracting: per_data/val_es/common_voice_es_18702137.mp3
#  extracting: per_data/val_es/common_voice_es_18703522.mp3
#  extracting: per_data/val_es/common_voice_es_18703523.mp3
#  extracting: per_data/val_es/common_voice_es_18703524.mp3
#  extracting: per_data/val_es/common_voice_es_18703525.mp3
#  extracting: per_data/val_es/common_voice_es_18703526.mp3
#  extracting: per_data/val_es/common_voice_es_18703527.mp3
#  extracting: per_data/val_es/common_voice_es_18703532.mp3
#  extracting: per_data/val_es/common_voice_es_18706204.mp3
#  extracting: per_data/val_es/common_voice_es_18721858.mp3
#  extracting: per_data/val_es/common_voice_es_18722129.mp3
#  extracting: per_data/val_es/common_voice_es_18727789.mp3
#  extracting: per_data/val_es/common_voice_es_18727790.mp3
#  extracting: per_data/val_es/common_voice_es_18727802.mp3
#  extracting: per_data/val_es/common_voice_es_18727806.mp3
#  extracting: per_data/val_es/common_voice_es_18727807.mp3
#  extracting: per_data/val_es/common_voice_es_18728446.mp3
#  extracting: per_data/val_es/common_voice_es_18728449.mp3
#  extracting: per_data/val_es/common_voice_es_18728451.mp3
#  extracting: per_data/val_es/common_voice_es_18728455.mp3
#  extracting: per_data/val_es/common_voice_es_18728456.mp3
#  extracting: per_data/val_es/common_voice_es_18735763.mp3
#  extracting: per_data/val_es/common_voice_es_18736689.mp3
#  extracting: per_data/val_es/common_voice_es_18750380.mp3
#  extracting: per_data/val_es/common_voice_es_18750381.mp3
#  extracting: per_data/val_es/common_voice_es_18750383.mp3
#  extracting: per_data/val_es/common_voice_es_18751722.mp3
#  extracting: per_data/val_es/common_voice_es_18754849.mp3
#  extracting: per_data/val_es/common_voice_es_18758543.mp3
#  extracting: per_data/val_es/common_voice_es_18765780.mp3
#  extracting: per_data/val_es/common_voice_es_18765918.mp3
#  extracting: per_data/val_es/common_voice_es_18765919.mp3
#  extracting: per_data/val_es/common_voice_es_18765920.mp3
#  extracting: per_data/val_es/common_voice_es_18770710.mp3
#  extracting: per_data/val_es/common_voice_es_18770711.mp3
#  extracting: per_data/val_es/common_voice_es_18775797.mp3
#  extracting: per_data/val_es/common_voice_es_18784517.mp3
#  extracting: per_data/val_es/common_voice_es_18784518.mp3
#  extracting: per_data/val_es/common_voice_es_18784520.mp3
#  extracting: per_data/val_es/common_voice_es_18786331.mp3
#  extracting: per_data/val_es/common_voice_es_18786332.mp3
#  extracting: per_data/val_es/common_voice_es_18789618.mp3
#  extracting: per_data/val_es/common_voice_es_18792587.mp3
#  extracting: per_data/val_es/common_voice_es_18794272.mp3
#  extracting: per_data/val_es/common_voice_es_18796570.mp3
#  extracting: per_data/val_es/common_voice_es_18796571.mp3
#  extracting: per_data/val_es/common_voice_es_18796573.mp3
#  extracting: per_data/val_es/common_voice_es_18809913.mp3
#  extracting: per_data/val_es/common_voice_es_18809918.mp3
#  extracting: per_data/val_es/common_voice_es_18811048.mp3
#  extracting: per_data/val_es/common_voice_es_18811056.mp3
#  extracting: per_data/val_es/common_voice_es_18811057.mp3
#  extracting: per_data/val_es/common_voice_es_18814364.mp3
#  extracting: per_data/val_es/common_voice_es_18832006.mp3
#  extracting: per_data/val_es/common_voice_es_18832007.mp3
#  extracting: per_data/val_es/common_voice_es_18832012.mp3
#  extracting: per_data/val_es/common_voice_es_18842643.mp3
#  extracting: per_data/val_es/common_voice_es_18842645.mp3
#  extracting: per_data/val_es/common_voice_es_18842647.mp3
#  extracting: per_data/val_es/common_voice_es_18845723.mp3
#  extracting: per_data/val_es/common_voice_es_18856534.mp3
#  extracting: per_data/val_es/common_voice_es_18856535.mp3
#  extracting: per_data/val_es/common_voice_es_18871349.mp3
#  extracting: per_data/val_es/common_voice_es_18871360.mp3
#  extracting: per_data/val_es/common_voice_es_18880321.mp3
#  extracting: per_data/val_es/common_voice_es_18885218.mp3
#  extracting: per_data/val_es/common_voice_es_18885219.mp3
#  extracting: per_data/val_es/common_voice_es_18885456.mp3
#  extracting: per_data/val_es/common_voice_es_18887203.mp3
#  extracting: per_data/val_es/common_voice_es_18898243.mp3
#  extracting: per_data/val_es/common_voice_es_18898245.mp3
#  extracting: per_data/val_es/common_voice_es_18898852.mp3
#  extracting: per_data/val_es/common_voice_es_18898853.mp3
#  extracting: per_data/val_es/common_voice_es_18898854.mp3
#  extracting: per_data/val_es/common_voice_es_18907032.mp3
#  extracting: per_data/val_es/common_voice_es_18918937.mp3
#  extracting: per_data/val_es/common_voice_es_18918938.mp3
#  extracting: per_data/val_es/common_voice_es_18918939.mp3

# %%
# %cd /content
ll_aligned  = drive.CreateFile({'id':'1CFDTYEGxvoqTRWqHCh_4M1kEEtTekeyD'})
ll_aligned.GetContentFile('per_data/pack_master.zip')
# !unzip per_data/pack_master.zip -d per_data/
# !ls
# Out:
# /content
# Archive:  per_data/pack_master.zip
#    creating: per_data/pack_master/
#   inflating: per_data/pack_master/10h_phones.txt
#    creating: per_data/pack_master/10min/
#    creating: per_data/pack_master/1h/
#    creating: per_data/pack_master/1h/0/
#    creating: per_data/pack_master/1h/0/clean/
#    creating: per_data/pack_master/1h/0/clean/3526/
#    creating: per_data/pack_master/1h/0/clean/3526/175658/
#   inflating: per_data/pack_master/1h/0/clean/3526/175658/3526-175658-0000.flac
#   inflating: per_data/pack_master/1h/0/clean/3526/175658/3526-175658-0002.flac
#   inflating: per_data/pack_master/1h/0/clean/3526/175658/3526-175658-0010.flac
#   inflating: per_data/pack_master/1h/0/clean/3526/175658/3526-175658-0003.flac
#   inflating: per_data/pack_master/1h/0/clean/3526/175658/3526-175658-0001.flac
#   inflating: per_data/pack_master/1h/0/clean/3526/175658/3526-175658-0009.flac
#   inflating: per_data/pack_master/1h/0/clean/3526/175658/3526-175658-0007.flac
#   inflating: per_data/pack_master/1h/0/clean/3526/175658/3526-175658-0005.flac
#   inflating: per_data/pack_master/1h/0/clean/3526/175658/3526-175658-0004.flac
#   inflating: per_data/pack_master/1h/0/clean/3526/175658/3526-175658.trans.txt
#   inflating: per_data/pack_master/1h/0/clean/3526/175658/3526-175658-0006.flac
#   inflating: per_data/pack_master/1h/0/clean/3526/175658/3526-175658-0008.flac
#    creating: per_data/pack_master/1h/0/clean/3607/
#    creating: per_data/pack_master/1h/0/clean/3607/135982/
#   inflating: per_data/pack_master/1h/0/clean/3607/135982/3607-135982-0009.flac
#   inflating: per_data/pack_master/1h/0/clean/3607/135982/3607-135982-0007.flac
#   inflating: per_data/pack_master/1h/0/clean/3607/135982/3607-135982-0005.flac
#   inflating: per_data/pack_master/1h/0/clean/3607/135982/3607-135982.trans.txt
#   inflating: per_data/pack_master/1h/0/clean/3607/135982/3607-135982-0004.flac
#   inflating: per_data/pack_master/1h/0/clean/3607/135982/3607-135982-0006.flac
#   inflating: per_data/pack_master/1h/0/clean/3607/135982/3607-135982-0008.flac
#   inflating: per_data/pack_master/1h/0/clean/3607/135982/3607-135982-0000.flac
#   inflating: per_data/pack_master/1h/0/clean/3607/135982/3607-135982-0002.flac
#   inflating: per_data/pack_master/1h/0/clean/3607/135982/3607-135982-0011.flac
#   inflating: per_data/pack_master/1h/0/clean/3607/135982/3607-135982-0003.flac
#   inflating: per_data/pack_master/1h/0/clean/3607/135982/3607-135982-
flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0010.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0037.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0024.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0050.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0003.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0036.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0011.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0038.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0042.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0002.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0051.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0025.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0027.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0053.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0029.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0000.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0040.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0013.flac
#   inflating: per_data/pack_master/10min/831/130746/831-130746-0034.flac
#    creating: per_data/pack_master/10min/831/130739/
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0021.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0055.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0015.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0046.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0061.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0048.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0032.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0030.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739.trans.txt
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0019.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0044.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0017.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0057.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0023.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0059.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0016.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0045.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0062.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0018.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0031.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0022.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0058.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0056.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0054.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0020.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0049.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0033.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0060.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0047.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0035.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0041.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0052.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0028.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0026.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0024.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0050.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0039.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0043.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0037.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0051.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0025.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0036.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0038.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0042.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0040.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0034.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0027.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0053.flac
#   inflating: per_data/pack_master/10min/831/130739/831-130739-0029.flac
#   inflating: per_data/pack_master/chars.txt
# adc.json		      __MACOSX	      sample_data     val_data
# converted_aligned_phones.txt  per_data	      train_data      val_data.zip
# gdrive			      phone_data.zip  train_data.zip

# %%
! git clone https://github.com/facebookresearch/CPC_audio.git  #
# Out:
# Cloning into 'CPC_audio'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 84 (delta 13), reused 75 (delta 6), pack-reused 0
# Unpacking objects: 100% (84/84), done.

# %%
# %cd /content/CPC_audio
# !python setup.py develop
# Out:
# /content/CPC_audio
# Compiling cpc/eval/ABX/dtw.pyx because it changed.
# [1/1] Cythonizing cpc/eval/ABX/dtw.pyx
# running develop
# running egg_info
# creating CPC_audio.egg-info
# writing CPC_audio.egg-info/PKG-INFO
# writing dependency_links to CPC_audio.egg-info/dependency_links.txt
# writing top-level names to CPC_audio.egg-info/top_level.txt
# writing manifest file 'CPC_audio.egg-info/SOURCES.txt'
# writing manifest file 'CPC_audio.egg-info/SOURCES.txt'
# running build_ext
# building 'cpc.eval.ABX.dtw' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/cpc
# creating build/temp.linux-x86_64-3.6/cpc/eval
# creating build/temp.linux-x86_64-3.6/cpc/eval/ABX
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/numpy/core/include -I/usr/include/python3.6m -c cpc/eval/ABX/dtw.c -o build/temp.linux-x86_64-3.6/cpc/eval/ABX/dtw.o
# In file included from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1832:0,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from cpc/eval/ABX/dtw.c:625:
# /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# creating build/lib.linux-x86_64-3.6
# creating build/lib.linux-x86_64-3.6/cpc
# creating build/lib.linux-x86_64-3.6/cpc/eval
# creating build/lib.linux-x86_64-3.6/cpc/eval/ABX
# x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.6/cpc/eval/ABX/dtw.o -o build/lib.linux-x86_64-3.6/cpc/eval/ABX/dtw.cpython-36m-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-3.6/cpc/eval/ABX/dtw.cpython-36m-x86_64-linux-gnu.so -> cpc/eval/ABX
# Creating /usr/local/lib/python3.6/dist-packages/CPC-audio.egg-link (link to .)
# Adding CPC-audio 1.0 to easy-install.pth file
#
# Installed /content/CPC_audio
# Processing dependencies for CPC-audio==1.0
# Finished processing dependencies for CPC-audio==1.0

# %%
import torch
import torchaudio

#    z ------- prediction_network  #### <----
#    ^           |
# context        |
#    ^
# encoder  --------- context
#    ^
# waveform -> raw audio data

# %% [markdown]
# # Part 1 : contrastive predictive coding
#
# Contrastive Predictive Coding (CPC) is a method of unsupervised training for speech models. The idea behind it is pretty simple:
#
#
# 1.   The raw audio wave is passed through a convolutional network: the ```encoder```
# 2.   Then, the encoder's output is given to a recurrent network the ```context```
# 3. A third party network, the ```prediction_network``` will try to predict the  future embeddings of the encoder using the output of the context network.
#
# In order to avoid a collapse to trivial solutions, the prediction_network doesn't try to reconstruct the future features. Instead, using the context output $c_t$ at time $t$ it is trained to discriminate the real  encoder representatioin $g_{t+k}$ at time $t+k$ from several other features $(g_n)_n$ taken elsewhere in the batch. Thus the loss becomes:
#
# \\[ \mathcal{L}_c = - \frac{1}{K} \sum_{k=1}^K \text{Cross_entropy}(\phi_k(c_t), g_{t+k}) \\]
#
# Or:
#
# \\[ \mathcal{L}_c = - \frac{1}{K} \sum_{k=1}^K \log \frac{ \exp\left(\phi_k(c_t)^\top g_{t+k}\right) }{  \sum_{\mathbf{n}\in\mathcal{N}_t} \exp\left(\phi_k(c_t)^\top g_n\right)} \\]
#
# Where:
#
#
# *   $\phi_k$ is the prediction network for the kth timestep
# *   $\mathcal{N}_t$ is the set of all negative examples sampled for timestep $t$

# %% [markdown]
# ## Exercise 1 : Building the model
#
# In this exercise, we will build and train a small CPC model using the repository CPC_audio.
#
# The code below loads a context and an encoder newtorks.

# %%
# %cd /content/CPC_audio
from cpc.model import CPCEncoder, CPCAR

DIM_ENCODER=256
DIM_CONTEXT=256
KEEP_HIDDEN_VECTOR=False
N_LEVELS_CONTEXT=1
CONTEXT_RNN="LSTM"
N_PREDICTIONS=12
LEARNING_RATE=2e-4
N_NEGATIVE_SAMPLE =128
# Out:
# /content/CPC_audio

# %%
encoder = CPCEncoder(DIM_ENCODER)
context = CPCAR(DIM_ENCODER,
                DIM_CONTEXT,
                KEEP_HIDDEN_VECTOR,
                N_LEVELS_CONTEXT,
                mode="CONTEXT_RNN")

# %%
# Several functions that will be necessary to load the data later
from cpc.dataset import findAllSeqs, AudioBatchData, parseSeqLabels
SIZE_WINDOW = 20480
BATCH_SIZE=8
def load_dataset(path_dataset, file_extension='.flac', phone_label_dict=None):
  data_list, speakers = findAllSeqs(path_dataset, extension=file_extension)
  dataset = AudioBatchData(path_dataset, SIZE_WINDOW, data_list, phone_label_dict, len(speakers))
  return dataset

# %% [markdown]
# Now build a new class, ```CPCModel``` which will

# %%
class CPCModel(torch.nn.Module):

    def __init__(self,
                 encoder,
                 AR):

        super(CPCModel, self).__init__()
        self.gEncoder = encoder
        self.gAR = AR

    def forward(self, batch_data):
        

        encoder_output = self.gEncoder(batch_data).permute(0, 2, 1)
       

        context_output = self.gAR(encoder_output)
        return context_output, encoder_output

# %% [markdown]
# Let's test your code !

# %%
audio = torchaudio.load("/content/train_data/831/130739/831-130739-0048.flac")[0]
audio = audio.view(1, 1, -1)
cpc_model = CPCModel(encoder, context)
context_output, encoder_output = cpc_model(audio)

# %% [markdown]
# ## Exercise 2 : CPC loss
#
# We will define a class ```CPCCriterion``` which will hold the prediction networks $\phi_k$ defined above and perform the classification loss $\mathcal{L}_c$.
#
# a) In this exercise, the $\phi_k$ will be a linear transform, ie:
#
# \\[ \phi_k(c_t) = \mathbf{A}_k c_t\\]
#
# Using the class [torch.nn.Linear](https://pytorch.org/docs/stable/nn.html#torch.nn.Linear), define the transformations $\phi_k$ in the code below and complete the function ```get_prediction_k``` which computes $\phi_k(c_t)$ for a given batch of vectors $c_t$.
#
# b) Using both ```get_prediction_k```  and ```sample_negatives``` defined below, write the forward function which will take as input two batches of features $c_t$ and $g_t$ and outputs the classification loss $\mathcal{L}_c$ and the average acuracy for all predictions.

# %%
# Exercice 2: write the CPC loss
# a) Write the negative sampling (with some help)
# ERRATUM: it's really hard, the sampling will be provided

class CPCCriterion(torch.nn.Module):

  def __init__(self,
               K,
               dim_context,
               dim_encoder,
               n_negative):
    super(CPCCriterion, self).__init__()
    self.K_ = K
    self.dim_context = dim_context
    self.dim_encoder = dim_encoder
    self.n_negative = n_negative

    self.predictors = torch.nn.ModuleList() 
    for k in range(self.K_):
      # TO COMPLETE !
      
      # A affine transformation in pytorch is equivalent to a nn.Linear layer
      # To get a linear transformation you must set bias=False
      # input dimension of the layer = dimension of the encoder
      # output dimension of the layer = dimension of the context
      self.predictors.append(torch.nn.Linear(self.dim_context, self.dim_encoder, bias=False))

  def get_prediction_k(self, context_data):

    #TO COMPLETE !
    output = [] 
    # For each time step k
    for k in range(self.K_):

      # We need to compute phi_k = A_k * c_t
      phi_k = self.predictors[k](context_data)
      output.append(phi_k)

    return output


  def sample_negatives(self, encoded_data):
    r"""
    Sample some negative examples in the given encoded data.
    Input:
    - encoded_data size: B x T x H
    Returns
    - outputs of size B x (n_negative + 1) x (T - K_) x H
      outputs[:, 0, :, :] contains the positive example
      outputs[:, 1:, :, :] contains negative example sampled in the batch
    - labels, long tensor of size B x (T - K_)
      Since the positive example is always at coordinates 0 for all sequences 
      in the batch and all timestep in the sequence, labels is just a tensor
      full of zeros !
    """
    batch_size, time_size, dim_encoded = encoded_data.size()
    window_size = time_size - self.K_
    outputs = []

    neg_ext = encoded_data.contiguous().view(-1, dim_encoded)
    n_elem_sampled = self.n_negative * window_size * batch_size
    # Draw nNegativeExt * batchSize negative samples anywhere in the batch
    batch_idx = torch.randint(low=0, high=batch_size,
                              size=(n_elem_sampled, ),
                              device=encoded_data.device)

    seq_idx = torch.randint(low=1, high=time_size,
                            size=(n_elem_sampled, ),
                            device=encoded_data.device)

    base_idx = torch.arange(0, window_size, device=encoded_data.device)
    base_idx = base_idx.view(1, 1, window_size)
    base_idx = base_idx.expand(1, self.n_negative, window_size)
    base_idx = base_idx.expand(batch_size, self.n_negative, window_size)
    seq_idx += base_idx.contiguous().view(-1)
    seq_idx = torch.remainder(seq_idx, time_size)

    ext_idx = seq_idx + batch_idx * time_size
    neg_ext = neg_ext[ext_idx].view(batch_size, self.n_negative,
                                    window_size, dim_encoded)

    label_loss = torch.zeros((batch_size, window_size),
                              dtype=torch.long,
                              device=encoded_data.device)

    for k in range(1, self.K_ + 1):

      # Positive samples
      if k < self.K_:
          pos_seq = encoded_data[:, k:-(self.K_-k)]
      else:
          pos_seq = encoded_data[:, k:]

      pos_seq = pos_seq.view(batch_size, 1, pos_seq.size(1), dim_encoded)
      full_seq = torch.cat((pos_seq, neg_ext), dim=1)
      outputs.append(full_seq)

    return outputs, label_loss

  def forward(self, encoded_data, context_data):

    # TO COMPLETE:
    # Perform the full cpc criterion
    # Returns 2 values:
    # - the average classification loss avg_loss
    # - the average classification acuracy avg_acc

    # Reminder : The permuation !
    encoded_data = encoded_data

    # First we need to sample the negative examples
    negative_samples, labels = self.sample_negatives(encoded_data)

    # Then we must compute phi_k
    phi_k = self.get_prediction_k(context_data)

    # Finally we must get the dot product between phi_k and negative_samples 
    # for each k

    #The total loss is the average of all losses
    avg_loss = 0

    # Average acuracy
    avg_acc = 0

    for k in range(self.K_):
      B, N_sampled, S_small, H = negative_samples[k].size() 
      B, S, H = phi_k[k].size()

      # As told before S = S_small + K. For segments too far in the sequence
      # there are no positive exmples anyway, so we must shorten phi_k
      phi = phi_k[k][:, :S_small]

      # Now the dot product
      # You have several ways to do that, let's do the simple but non optimal 
      # one
      # pytorch has a matrix product function https://pytorch.org/docs/stable/torch.html#torch.bmm
      # But it takes only 3D tensors of the same batch size !
      # To begin negative_samples is a 4D tensor ! 
      # We want to compute the dot product for each features, of each sequence
      # of the batch. Thus we are trying to compute a dot product for all
      # B* N_sampled * S_small 1D vector of negative_samples[k]
      # Or, a 1D tensor of size H is also a matrix of size 1 x H
      # Then, we must view it as a 3D tensor of size (B* N_sampled * S_small, 1, H)
      negative_sample_k  =  negative_samples[k].view(B* N_sampled* S_small, 1, H)

      # But now phi and negative_sample_k no longer have the same batch size !
      # No worries, we can expand phi so that each sequence of the batch
      # is repeated N_sampled times
      phi = phi.view(B, 1,S_small, H).expand(B, N_sampled, S_small, H)

      # And now we can view it as a 3D tensor 
      phi  = phi.contiguous().view(B * N_sampled * S_small, H, 1)

      # We can finally get the dot product !
      scores = torch.bmm(negative_sample_k, phi)

      # Dot_product has a size (B * N_sampled * S_small , 1, 1)
      # Let's reorder it a bit
      scores = scores.view(B, N_sampled, S_small)

      # For each elements of the sequence, and each elements sampled, it gives 
      # a floating score stating the likelihood of this element being the 
      # true one.
      # Now the classification loss, we need to use the Cross Entropy loss
      # https://pytorch.org/docs/master/generated/torch.nn.CrossEntropyLoss.html

      # For each time-step of each sequence of the batch 
      # we have N_sampled possible predictions. 
      # Looking at the documentation of torch.nn.CrossEntropyLoss
      # we can see that this loss expect a tensor of size M x C where 
      # - M is the number of elements with a classification score
      # - C is the number of possible classes
      # There are N_sampled candidates for each predictions so
      # C = N_sampled 
      # Each timestep of each sequence of the batch has a prediction so
      # M = B * S_small
      # Thus we need an input vector of size B * S_small, N_sampled
      # To begin, we need to permute the axis
      #scores = scores.permute(0, 2, 1) # Now it has size B , S_small, N_sampled

      # Then we can cast it into a 2D tensor
      scores = scores.view(B * S_small, N_sampled)

      # Same thing for the labels 
      labels = labels.view(B * S_small)

      # Finally we can get the classification loss
      loss_criterion = torch.nn.CrossEntropyLoss()
      loss_k = loss_criterion(scores, labels)
      avg_loss+= loss_k

      # And for the acuracy
      # The prediction for each elements is the sample with the highest score
      # Thus the tensors of all predictions is the tensors of the index of the 
      # maximal score for each time-step of each sequence of the batch
      predictions = torch.argmax(scores, 1)
      acc_k  = (labels == predictions) / (B * S_small)
      avg_acc += acc_k

    # Normalization
    avg_loss = avg_loss / self.K_
    avg_acc = avg_acc / self.K_
      
    return avg_loss , avg_acc

# %% [markdown]
# Don't forget to test !

# %%
audio = torchaudio.load("/content/train_data/831/130739/831-130739-0048.flac")[0]
audio = audio.view(1, 1, -1)
cpc_criterion = CPCCriterion(N_PREDICTIONS, DIM_ENCODER, 
                             DIM_CONTEXT, N_NEGATIVE_SAMPLE)
context_output, encoder_output = cpc_model(audio)
loss, avg = cpc_criterion(context_output, encoder_output)
# Out:
# /pytorch/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.

# %% [markdown]
# ## Exercise 3: Full training loop !
#
# You have the model, you have the criterion. All you need now are a data loader and an optimizer to run your training loop.
#
# We will use an Adam optimizer:

# %%
parameters = list(cpc_criterion.parameters()) + list(cpc_model.parameters())
optimizer = torch.optim.Adam(parameters, lr=LEARNING_RATE)

# %% [markdown]
# And as far as the data loader is concerned, we will rely on the data loader provided by the CPC_audio library.

# %%
dataset_train = load_dataset('/content/train_data')
dataset_val = load_dataset('/content/val_data')
data_loader_train = dataset_train.getDataLoader(BATCH_SIZE, "speaker", True)
data_loader_val = dataset_train.getDataLoader(BATCH_SIZE, "sequence", False)
# Out:
# 162it [00:00, 11192.36it/s]
# Saved cache file at /content/train_data/_seqs_cache.txt
# 1430it [00:00, 392709.67it/s]
# Checking length...
# Done, elapsed: 0.093 seconds
# Scanned 1430 sequences in 0.09 seconds
# 1 chunks computed
# Joining pool
# Joined process, elapsed=5.705 secs
# 169it [00:00, 20017.43it/s]
# Saved cache file at /content/val_data/_seqs_cache.txt
# 316it [00:00, 683195.91it/s]
# Checking length...
# Done, elapsed: 0.075 seconds
# Scanned 316 sequences in 0.07 seconds
# 1 chunks computed
# Joining pool
# Joined process, elapsed=2.491 secs

# %% [markdown]
# Now that everything is ready, complete and test the ```train_step``` function below which trains the model for one epoch.

# %%
def train_step(data_loader,
               cpc_model,
               cpc_criterion,
               optimizer):
  
  avg_loss = 0
  avg_acc = 0
  n_items = 0

  for step, data in enumerate(dataLoader):
    # COMPLETE
    optimizer.zero_grad()

    x, y = data[0], data[0]
    #context_data, encoder_data = cpc_criterion(cpc_model)
    loss = cpc_criterion(encoded_data, context_data)
    loss.mean().backward()

    avg_loss += loss.item()
     

    n_items += 1
  avg_acc /= n_items

  return avg_loss, avg_acc

# %% [markdown]
# ## Exercise 4 : Validation loop
#
# Now complete the validation loop.

# %%
def validation_step(data_loader,
                    cpc_model,
                    cpc_criterion):
  
  avg_loss = 0
  avg_acc = 0
  n_items = 0

  for step, data in enumerate(dataLoader):
    # TO COMPLETE
    x, y = data[0], data[0]
    loss = cpc_critetrion(encoded_data, context_data)

    avg_loss += loss.item()

    n_items += 1
  avg_acc /= n_items

  return avg_loss, avg_acc

# %% [markdown]
# ## Exercise 5: Run everything

# %%
def run(train_loader,
        val_loader,
        cpc_model,
        cpc_criterion,
        optimizer,
        n_epochs):
  
  for epoch in range(n_epochs):

    
    print(f"Running epoch {epoch+1} / {n_epochs}")
    avg_loss_train, avg_acc_train = train_step(train_loader, cpc_model, cpc_criterion, optimizer)
    print("----------------------")
    print(f"Training dataset")
    print(f"- average loss : {avg_loss_train}")
    print(f"- average acuracy : {avg_acc_train}")
    print("----------------------")

    avg_loss_val, avg_acc_val = train_step(val_loader, cpc_model, cpc_criterion)
    print(f"Validation dataset")
    print(f"- average loss : {avg_loss_train}")
    print(f"- average acuracy : {avg_acc_train}")
    print("----------------------")
    print()

# %% [markdown]
# Once everything is donw, clear the memory.

# %%
del dataset_train
del dataset_val
del cpc_model
del context
del encoder

# %% [markdown]
# # Part 2 : Fine tuning

# %% [markdown]
# ## Exercice 1 : Phone separability with aligned phonemes.
#
# One option to evaluate the quality of the features trained with CPC can be to check if they can be used to recognize phonemes.
# To do so, we can fine-tune a pre-trained model using a limited amount of labelled speech data.
# We are going to start with a simple evaluation setting where we have the phone labels for each timestep corresponding to a CPC feature.
#
# We will work with a model already pre-trained on English data. As far as the fine-tuning dataset is concerned, we will use a 1h subset of [librispeech-100](http://www.openslr.org/12/).

# %%
# !mkdir checkpoint_data
# !wget https://dl.fbaipublicfiles.com/librilight/CPC_checkpoints/not_hub/2levels_6k_top_ctc/checkpoint_30.pt -P checkpoint_data
# !wget https://dl.fbaipublicfiles.com/librilight/CPC_checkpoints/not_hub/2levels_6k_top_ctc/checkpoint_logs.json -P checkpoint_data
# !wget https://dl.fbaipublicfiles.com/librilight/CPC_checkpoints/not_hub/2levels_6k_top_ctc/checkpoint_args.json -P checkpoint_data
# !ls checkpoint_data
# Out:
# --2020-06-29 10:25:47--  https://dl.fbaipublicfiles.com/librilight/CPC_checkpoints/not_hub/2levels_6k_top_ctc/checkpoint_30.pt
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 104.22.75.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113599715 (108M) [application/octet-stream]
# Saving to: ‘checkpoint_data/checkpoint_30.pt’
#
# checkpoint_30.pt    100%[===================>] 108.34M  24.1MB/s    in 5.0s
#
# 2020-06-29 10:25:52 (21.6 MB/s) - ‘checkpoint_data/checkpoint_30.pt’ saved [113599715/113599715]
#
# --2020-06-29 10:25:54--  https://dl.fbaipublicfiles.com/librilight/CPC_checkpoints/not_hub/2levels_6k_top_ctc/checkpoint_logs.json
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 172.67.9.4, 104.22.74.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20786 (20K) [text/plain]
# Saving to: ‘checkpoint_data/checkpoint_logs.json’
#
# checkpoint_logs.jso 100%[===================>]  20.30K  --.-KB/s    in 0.08s
#
# 2020-06-29 10:25:54 (252 KB/s) - ‘checkpoint_data/checkpoint_logs.json’ saved [20786/20786]
#
# --2020-06-29 10:25:55--  https://dl.fbaipublicfiles.com/librilight/CPC_checkpoints/not_hub/2levels_6k_top_ctc/checkpoint_args.json
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 104.22.75.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2063 (2.0K) [text/plain]
# Saving to: ‘checkpoint_data/checkpoint_args.json’
#
# checkpoint_args.jso 100%[===================>]   2.01K  --.-KB/s    in 0s
#
# 2020-06-29 10:25:56 (15.4 MB/s) - ‘checkpoint_data/checkpoint_args.json’ saved [2063/2063]
#
# checkpoint_30.pt  checkpoint_args.json	checkpoint_logs.json

# %%
# %cd /content/CPC_audio
from cpc.dataset import parseSeqLabels
from cpc.feature_loader import loadModel

checkpoint_path = 'checkpoint_data/checkpoint_30.pt'
cpc_model, HIDDEN_CONTEXT_MODEL, HIDDEN_ENCODER_MODEL = loadModel([checkpoint_path])
cpc_model = cpc_model.cuda()
label_dict, N_PHONES = parseSeqLabels('/content/converted_aligned_phones.txt')
dataset_train = load_dataset('/content/train_data', file_extension='.flac', phone_label_dict=label_dict)
dataset_train = load_dataset('/content/val_data', file_extension='.flac', phone_label_dict=label_dict)
data_loader_train = dataset_train.getDataLoader(BATCH_SIZE, "speaker", True)
data_loader_val = dataset_train.getDataLoader(BATCH_SIZE, "sequence", False)
# Out:
# /content/CPC_audio
# Loading checkpoint checkpoint_data/checkpoint_30.pt
# Loading the state dict at checkpoint_data/checkpoint_30.pt
# 162it [00:00, 3738.84it/s]
# Saved cache file at /content/train_data/_seqs_cache.txt
# Checking length...
# 1430it [00:00, 407131.06it/s]
# Done, elapsed: 1.799 seconds
# Scanned 1430 sequences in 1.80 seconds
# 1 chunks computed
# Joining pool
# Joined process, elapsed=7.338 secs
# 169it [00:00, 470.92it/s]
# Saved cache file at /content/val_data/_seqs_cache.txt
# 316it [00:00, 50667.08it/s]
# Checking length...
# Done, elapsed: 0.057 seconds
# Scanned 316 sequences in 0.06 seconds
# 1 chunks computed
# Joining pool
# Joined process, elapsed=1.434 secs

# %% [markdown]
# Then we will use a simple linear classifier to recognize the phonemes from the features produced by ```cpc_model```.
#
# ### a) Build the phone classifier
#
# Design a class of linear classifiers, ```PhoneClassifier``` that will take as input a batch of sequences of CPC features and output a score vector for each phoneme

# %%
class PhoneClassifier(torch.nn.Module):

  def __init__(self,
               input_dim : int,
               n_phones : int):
    super(PhoneClassifier, self).__init__()
    self.linear = torch.nn.Linear(input_dim,n_phones)
    
  def forward(self, x):
    x = self.linear(x)
    return(x)

# %% [markdown]
# Our phone classifier will then be:

# %%
phone_classifier = PhoneClassifier(HIDDEN_CONTEXT_MODEL, N_PHONES)

# %% [markdown]
# ### b - What would be the correct loss criterion for this task ?

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
loss_criterion = nn.CrossEntropyLoss()

# %% [markdown]
# To perform the fine-tuning, we will also need an optimization function.
#
# We will use an [Adam optimizer ](https://pytorch.org/docs/stable/optim.html#torch.optim.Adam).

# %%
parameters = list(phone_classifier.parameters()) + list(cpc_model.parameters())
LEARNING_RATE = 2e-4
optimizer = optim.Adam(parameters, lr=LEARNING_RATE)

# %% [markdown]
# You might also want to perform this training while freezing the weights of the ```cpc_model```. Indeed, if the pre-training was good enough, then ```cpc_model``` phonemes representation should be linearly separable. In this case the optimizer should be defined like this:

# %%
optimizer_frozen = optim.Adam(list(phone_classifier.parameters()), lr=LEARNING_RATE)

# %% [markdown]
# ### c- Now let's build a training loop.
# Complete the function ```train_one_epoch``` below.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

def train_one_epoch(cpc_model,
  phone_classifier,
  loss_criterion,
  data_loader,
  optimizer):

  cpc_model.train()
  loss_criterion.train()

  avg_loss = 0
  avg_acc = 0
  avg_accuracy = 0
  avg_loss_cpc = 0
  n_items = 0

  for step, full_data in enumerate(data_loader):

    # Each batch is represented by a Tuple of vectors:
    # sequence of size : N x 1 x T
    # label of size : N x T
    #
    # With :
    # - N number of sequence in the batch
    # - T size of each sequence
    sequence, label = full_data
    sequence, label = sequence.to(device), label.to(device)

    # TO COMPLETE
    # At the end of the epoch, we should retrieve the average
    # loss and the average classification acuracy
    # computer on the training dataset.
    optimizer.zero_grad()

    out = cpc_model(sequence, label)
    phone_classifier = phone_classifier.to(device)
    pred = phone_classifier(out[0])
    pred = pred.view(-1, pred.size(2))
    label = label.view(-1)
    loss= loss_criterion(pred, label).view(1, -1)
    avg_loss += loss.item()

    loss.backward()
    optimizer_frozen.step()
    n_items += 1

  avg_loss /= n_items
  avg_accuracy = (pred.max(1)[1] == label).double().mean().view(1, -1)

  return avg_loss, avg_accuracy

# %% [markdown]
# Don't forget to test it !

# %%
avg_loss, avg_accuracy = train_one_epoch(cpc_model, phone_classifier, loss_criterion, data_loader_train, optimizer_frozen)

# %% [markdown]
# ### d- Build the validation loop

# %%
def validation_step(cpc_model, 
                    phone_classifier, 
                    loss_criterion, 
                    data_loader):
  
  cpc_model.eval()
  phone_classifier.eval()

  avg_loss = 0
  avg_accuracy = 0
  n_items = 0

  for step, full_data in enumerate(data_loader):

    # Each batch is represented by a Tuple of vectors:
    # sequence of size : N x 1 x T
    # label of size : N x T
    # 
    # With :
    # - N number of sequence in the batch
    # - T size of each sequence
    sequence, label = full_data

    sequence, label = sequence.to(device), label.to(device)

    out = cpc_model(sequence, label)
    phone_classifier = phone_classifier.to(device)
    pred = phone_classifier(out[0])
    pred = pred.view(-1, pred.size(2))
    label = label.view(-1)
    loss= loss_criterion(pred, label).view(1, -1)
    avg_loss += loss.item()

    optimizer_frozen.step()
    n_items += 1

    avg_loss /= n_items
  avg_accuracy = (pred.max(1)[1] == label).double().mean().view(1, -1)

  return avg_loss, avg_accuracy

# %% [markdown]
# ### e- Run everything
#
# Test this functiion with both ```optimizer``` and ```optimizer_frozen```.

# %%
def run(cpc_model, 
        phone_classifier, 
        loss_criterion, 
        data_loader_train, 
        data_loader_val, 
        optimizer,
        n_epoch):

  for epoch in range(n_epoch):

    print(f"Running epoch {epoch + 1} / {n_epoch}")
    loss_train, acc_train = train_one_epoch(cpc_model, phone_classifier, loss_criterion, data_loader_train, optimizer)
    print("-------------------")
    print(f"Training dataset :")
    print(f"Average loss : {loss_train}. Average accuracy {acc_train}")

    print("-------------------")
    print("Validation dataset")
    loss_val, acc_val = validation_step(cpc_model, phone_classifier, loss_criterion, data_loader)
    print(f"Average loss : {loss_val}. Average accuracy {acc_val}")
    print("-------------------")
    print()

# %% [markdown]
# ## Exercise 2 : Phone separability without alignment (PER)
#
# Aligned data are very practical, but un real life they are rarely available. That's why in this excercise we will consider a fine-tuning with non-aligned phonemes.
#
# The model, the optimizer and the phone classifier will stay the same. However, we will replace our phone criterion with a [CTC loss](https://pytorch.org/docs/master/generated/torch.nn.CTCLoss.html).

# %%
loss_ctc = torch.nn.CTCLoss()

# %% [markdown]
# Besides, we will use a siglthy different dataset class.

# %%
# %cd /content/CPC_audio
from cpc.eval.common_voices_eval import SingleSequenceDataset, parseSeqLabels, findAllSeqs
path_train_data_per = '/content/per_data/pack_master/1h'
path_val_data_per = '/content/per_data/pack_master/10min'
path_phone_data_per = '/content/per_data/pack_master/10h_phones.txt'
BATCH_SIZE=8

phone_labels, N_PHONES = parseSeqLabels(path_phone_data_per)
data_train_per, _ = findAllSeqs(path_train_data_per, extension='.flac')
dataset_train_non_aligned = SingleSequenceDataset(path_train_data_per, data_train_per, phone_labels)
data_loader_train = torch.utils.data.DataLoader(dataset_train_non_aligned, batch_size=BATCH_SIZE,
                                                shuffle=True)

data_val_per, _ = findAllSeqs(path_val_data_per, extension='.flac')
dataset_val_non_aligned = SingleSequenceDataset(path_val_data_per, data_val_per, phone_labels)
data_loader_val = torch.utils.data.DataLoader(dataset_val_non_aligned, batch_size=BATCH_SIZE,
                                              shuffle=True)
# Out:
# 67it [00:00, 3379.62it/s]
# /content/CPC_audio
# Saved cache file at /content/per_data/pack_master/1h/_seqs_cache.txt
# 7it [00:00, 1336.43it/s]
# Loaded 287 sequences in 4.51 seconds
# maxSizeSeq : 273359
# maxSizePhone : 207
# minSizePhone : 17
# Total size dataset 1.0406152430555555 hours
# Saved cache file at /content/per_data/pack_master/10min/_seqs_cache.txt
# Loaded 212 sequences in 4.80 seconds
# maxSizeSeq : 273760
# maxSizePhone : 188
# minSizePhone : 17
# Total size dataset 0.73 hours

# %% [markdown]
# ### a- Training
#
# Since the phonemes are not aligned, there is no simple direct way to get the classification acuracy of a model. Write and test the three functions ```train_one_epoch_ctc```, ```validation_step_ctc``` and ```run_ctc``` as before but without considering the average acuracy of the model.

# %%
def train_one_epoch_ctc(cpc_model, 
                        phone_classifier, 
                        loss_criterion, 
                        data_loader, 
                        optimizer):
  cpc_model.train()
  loss_criterion.train()

  
  avg_accuracy = 0
  avg_loss_cpc = 0
  n_items = 0
  phone_classifier = phone_classifier.to(device)

  for step, full_data in enumerate(data_loader):
    print(len(full_data))

    sequence, label = full_data
    sequence, label = sequence.to(device), label.to(device)

    # TO COMPLETE
    # At the end of the epoch, we should retrieve the average
    # loss and the average classification acuracy
    # computer on the training dataset.
    optimizer.zero_grad()

    out = cpc_model(sequence, label)
    
    pred = phone_classifier(out[0])


  return avg_loss_cpc

def validation_step(cpc_model, 
                    phone_classifier, 
                    loss_criterion, 
                    data_loader):
  
  cpc_model.eval()
  phone_classifier.eval()

  avg_loss = 0
  avg_accuracy = 0
  n_items = 0

  for step, full_data in enumerate(data_loader):
    print(type(full_data))
    sequence, label = full_data

    sequence, label = sequence.to(device), label.to(device)

    out = cpc_model(sequence, label)
    phone_classifier = phone_classifier.to(device)
    pred = phone_classifier(out[0])

    input_lengths = torch.full(size=(B,), fill_value=8, dtype=torch.long)
    target_lengths = torch.randint(10,41,(B,), dtype=torch.long)

    loss= loss_criterion(pred, label, input_len, target_len).view(1, -1)
    avg_loss += loss.item()

    n_items += 1

  avg_loss /= n_items
  return avg_loss

def run_ctc(cpc_model, 
            phone_classifier, 
            loss_criterion, 
            data_loader_train, 
            data_loader_val, 
            optimizer,
            n_epoch):
  # TO COMPLETE
  pass

# %% [markdown]
# ### b- Evaluation: the Phone Error Rate (PER)
#
# In order to compute the similarity between two sequences, we can use the [Levenshtein distance](https://en.wikipedia.org/wiki/Levenshtein_distance). This distance estimates the minimum number of insertion, deletion and addition to move from one sequence to another. If we normalize this distance by the number of characters in the reference sequence we get the Phone Error Rate (PER).
#
# This value can be interpreted as :
# \\[  PER = \frac{S + D + I}{N} \\]
#
# Where:
#
#
# *   N is the number of characters in the reference
# *   S is the number of substitutiion
# *   I in the number of insertion
# *   D in the number of deletion
#
# For the best possible alignment of the two sequences.

# %%
import numpy as np
def get_PER_sequence(g, h):
    m = len(g)
    n = len(h)
    a = 0
    b = 0
    c = 0
    matrix = np.zeros((m + 1, n + 1))

    for i in range(m + 1):
        matrix[i][0] = i

    for j in range(n + 1):
        matrix[0][j] = j
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if (g[i-1] == h[j-1]):
                matrix[i][j] = matrix[i - 1][j - 1]
            else:
                a = matrix[i][j - 1]
                b = matrix[i - 1][j]
                c = matrix[i - 1][j - 1]
                if (a <= b and a <= c):
                    matrix[i][j] = a + 1
                elif (b <= a and b <= c):
                    matrix[i][j] = b + 1
                else:
                    matrix[i][j] = c + 1
    PER = matrix[m][n]/m
    return PER

# %% [markdown]
# You can test your function below:

# %%
ref_seq = [0, 1, 1, 2, 0, 2, 2]
pred_seq = [1, 1, 2, 2, 0, 0]

expected_PER = 4. / 7.
print(get_PER_sequence(ref_seq, pred_seq) == expected_PER)
# Out:
# True

# %% [markdown]
# ## c- Evaluating the PER of your model on the test dataset
#
# Evaluate the PER on the validation dataset. Please notice that you should usually use a separate dataset, called the dev dataset, to perform this operation. However for the sake of simplicity we will work with validation data in this exercise.

# %%
import progressbar

def cut_data(seq, sizeSeq):
    maxSeq = sizeSeq.max()
    return seq[:, :maxSeq]


def prepare_data(data):
    seq, sizeSeq, phone, sizePhone = data
    seq = seq.cuda()
    phone = phone.cuda()
    sizeSeq = sizeSeq.cuda().view(-1)
    sizePhone = sizePhone.cuda().view(-1)

    seq = cut_data(seq.permute(0, 2, 1), sizeSeq).permute(0, 2, 1)
    return seq, sizeSeq, phone, sizePhone


def get_per(test_dataloader,
            cpc_model,
            phone_classifier):

  downsampling_factor = 160
  cpc_model.eval()
  phone_classifier.eval()

  avgPER = 0

  print("Starting the PER computation through beam search")
  bar = progressbar.ProgressBar(maxval=len(test_dataloader))
  bar.start()

  for index, data in enumerate(test_dataloader):

    bar.update(index)

    with torch.no_grad():
      
        seq, sizeSeq, phone, sizePhone = prepare_data(data)
        c_feature, _, _ = cpc_model(seq)
        sizeSeq = sizeSeq / downsampling_factor
        predictions = torch.nn.functional.softmax(
        phone_classifier(c_feature, sizeSeq), dim=2).cpu()
        phone = phone.cpu()
        sizeSeq = sizeSeq.cpu()
        sizePhone = sizePhone.cpu()

        bs = c_feature.size(0)
        data_per = [(predictions[b], sizeSeq[b], phone[b], sizePhone[b],
                      criterion.module.BLANK_LABEL) for b in range(bs)]

        with Pool(bs) as p:
            poolData = p.map(get_per, data_per)
        avgPER += sum([x for x in poolData])
        nItems += len(poolData)

  bar.finish()

  avgPER /= nItems

  print(f"Average PER {avgPER}")
  return avgPER

# %% [markdown]
# ## Exercice 3 : Character error rate (CER)
#
# The Character Error Rate (CER) is an evaluation metric similar to the PER but with characters insterad of phonemes. Using the following data, run the functions you defined previously to estimate the CER of your model after fine-tuning.

# %%
# Load a dataset labelled with the letters of each sequence.
# %cd /content/CPC_audio
from cpc.eval.common_voices_eval import SingleSequenceDataset, parseSeqLabels, findAllSeqs
path_train_data_cer = '/content/per_data/pack_master/1h'
path_val_data_cer = '/content/per_data/pack_master/10min'
path_letter_data_cer = '/content/per_data/pack_master/chars.txt'
BATCH_SIZE=8

letters_labels, N_LETTERS = parseSeqLabels(path_letter_data_cer)
data_train_cer, _ = findAllSeqs(path_train_data_cer, extension='.flac')
dataset_train_non_aligned = SingleSequenceDataset(path_train_data_cer, data_train_cer, letters_labels)


data_val_cer, _ = findAllSeqs(path_val_data_cer, extension='.flac')
dataset_val_non_aligned = SingleSequenceDataset(path_val_data_cer, data_val_cer, letters_labels)


# The data loader will generate a tuple of tensors data, labels for each batch
# data : size N x T1 x 1 : the audio sequence
# label : size N x T2 the sequence of letters corresponding to the audio data
# IMPORTANT NOTE: just like the PER the CER is computed with non-aligned phone data.
data_loader_train_letters = torch.utils.data.DataLoader(dataset_train_non_aligned, batch_size=BATCH_SIZE,
                                                shuffle=True)
data_loader_val_letters = torch.utils.data.DataLoader(dataset_val_non_aligned, batch_size=BATCH_SIZE,
                                              shuffle=True)
# Out:
# 67it [00:00, 14602.91it/s]
# /content/CPC_audio
# Saved cache file at /content/per_data/pack_master/1h/_seqs_cache.txt
# 7it [00:00, 4514.16it/s]
# Loaded 287 sequences in 4.20 seconds
# maxSizeSeq : 273359
# maxSizePhone : 300
# minSizePhone : 18
# Total size dataset 1.0406152430555555 hours
# Saved cache file at /content/per_data/pack_master/10min/_seqs_cache.txt
# Loaded 212 sequences in 3.31 seconds
# maxSizeSeq : 273760
# maxSizePhone : 273
# minSizePhone : 29
# Total size dataset 0.73 hours

# %% [markdown]
# # Part 3 : Phonemes recognition without pre-training
#
# Let's estimate the impact of the pre-training by estimating the PER of a model trained from scratch on the labelled dataset.

# %% [markdown]
# ## Exercice 1: training from scratch on the labelled dataset
#
# What kind of performance will you get if you try to launch the fine-tuning without pre-training ? Check out the PER and the CER of ```cpc_non_pre_trained``` below.

# %%
encoder =  CPCEncoder(hidden_dim)
context = CPCAR(DIM_ENCODER, DIM_CONTEXT, KEEP_HIDDEN_VECTOR, N_LEVELS_CONTEXT, mode=CONTEXT_RNN)
cpc_non_pre_trained = CPCModel(encoder, context)

# %% [markdown]
# ## Exercice 2: Comparison with hand-crafted ASR features
#
# Now replace train a phone classifier on top of MFCC features. What PER do you get ?
#
# See [here](https://pytorch.org/audio/transforms.html#torchaudio.transforms.MFCC) to build MFCC features.

# %%
mfcc_crafter = # Good luck !
